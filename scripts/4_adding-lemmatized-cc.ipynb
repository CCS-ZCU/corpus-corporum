# %%
import os
import re
from bs4 import BeautifulSoup, NavigableString

# %%
def map_cc_pos(pos_tag, token_text):
    if pos_tag is None:
        return "X"

    if pos_tag.startswith("V:"):
        return "VERB"
    if pos_tag.startswith("N:"):
        return "NOUN"
    if pos_tag.startswith("ADJ"):
        return "ADJ"
    if pos_tag.startswith("ADV"):
        return "ADV"
    if pos_tag.startswith("PREP"):
        return "ADP"
    if pos_tag in {"CC", "CON", "CS"}:
        return "CCONJ" if pos_tag == "CC" else "SCONJ"
    if pos_tag in {"PRON", "REL", "DIMOS", "POSS", "DET"}:
        return "PRON"
    if pos_tag == "NUM" or "NUM" in pos_tag:
        return "NUM"
    if token_text and token_text[0].isupper():
        if pos_tag.startswith("N:") or pos_tag == "????":
            return "PROPN"
    return "X"

# %%
def parse_lemmatized_cc(filename):
    from bs4 import NavigableString

    with open(filename, "r", encoding="utf-8") as f:
        soup = BeautifulSoup(f, "html.parser")

    work_id = re.search(r'\d+', filename).group()
    sentences = []
    position = 0

    for div in soup.find_all("div", attrs={"cc:pid": True}):
        subwork_id = div.get("cc:pid").split(":", 1)[1] if ":" in div.get("cc:pid") else None

        for s_elem in div.find_all("cc:s", recursive=True):
            if not s_elem.get("n") or not s_elem.get("parent_pid"):
                continue

            sentence_tokens = []
            token_data = []
            char_index = 0

            for w in s_elem.find_all("cc:w"):
                token_text = w.text.strip()
                if not token_text:
                    continue

                lemma = re.sub(r"\d+$", "", w.get("lemma") or "")
                pos = map_cc_pos(w.get("pos"), token_text)

                start = char_index
                end = start + len(token_text)
                char_index = end + 1

                token_data.append({
                    "token_text": token_text,
                    "lemma": lemma,
                    "pos": pos,
                    "ref": subwork_id,
                    "char_start": start,
                    "char_end": end
                })
                sentence_tokens.append(token_text)
            sentence_tokens = [t[0] + t[1:].lower() if len(t) > 2 else t for t in sentence_tokens if t is not None and t != ""]
            if sentence_tokens:
                sentences.append({
                    "work_id": work_id,
                    "sent_id" : position,
                    "sent_text" : " ".join(sentence_tokens),
                    "tokens_data" : token_data
                })
                position += 1
    return sentences

# %%
source_path = "../data/lemmatized-xmls/"
os.listdir(source_path)
# Out:
# ['cc_16855_Petrus-Damiani_Liber-gratissimus.POS.xml',
#  'cc_10265_Gregorius-VII_Registrum.POS.xml',
#  'cc_10122_Petrus-Damianus_Liber-Gomorrhianus-ad-Leonem-IX.POS.xml',
#  'cc_20329_Benzo-Albensis_Ad-Heinricum-IV.-imperatorem-libri-VII.POS.xml',
#  'cc_10045_Petrus-Damianus_Epistolae.POS.xml',
#  'cc_16780_Petrus-Damiani_Disceptatio-synodalis.POS.xml']

# %%
filename = os.listdir(source_path)[0]
sentences = parse_lemmatized_cc(os.path.join(source_path, filename))

# %%
sentences[:10]
# Out:
# [{'work_id': '16855',
#   'sent_id': 0,
#   'sent_text': 'Liber gratissimus',
#   'tokens_data': [{'token_text': 'Liber',
#     'lemma': 'liber',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 5},
#    {'token_text': 'gratissimus',
#     'lemma': '????',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 6,
#     'char_end': 17}]},
#  {'work_id': '16855',
#   'sent_id': 1,
#   'sent_text': 'Versus de symoniacis',
#   'tokens_data': [{'token_text': 'Versus',
#     'lemma': 'versus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 6},
#    {'token_text': 'de',
#     'lemma': 'de',
#     'pos': 'ADP',
#     'ref': '1',
#     'char_start': 7,
#     'char_end': 9},
#    {'token_text': 'symoniacis',
#     'lemma': '????',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 10,
#     'char_end': 20}]},
#  {'work_id': '16855',
#   'sent_id': 2,
#   'sent_text': 'Incudem Symonis fabrilis et antra monetae Damnat pestiferas Deus evertendo cathedras',
#   'tokens_data': [{'token_text': 'Incudem',
#     'lemma': 'incus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 7},
#    {'token_text': 'Symonis',
#     'lemma': '????',
#     'pos': 'PROPN',
#     'ref': '1',
#     'char_start': 8,
#     'char_end': 15},
#    {'token_text': 'fabrilis',
#     'lemma': 'fabrilis',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 16,
#     'char_end': 24},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': '1',
#     'char_start': 25,
#     'char_end': 27},
#    {'token_text': 'antra',
#     'lemma': 'antrum',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 28,
#     'char_end': 33},
#    {'token_text': 'monetae',
#     'lemma': 'moneta',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 34,
#     'char_end': 41},
#    {'token_text': 'Damnat',
#     'lemma': 'damno',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 42,
#     'char_end': 48},
#    {'token_text': 'pestiferas',
#     'lemma': 'pestifer',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 49,
#     'char_end': 59},
#    {'token_text': 'Deus',
#     'lemma': 'Deus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 60,
#     'char_end': 64},
#    {'token_text': 'evertendo',
#     'lemma': 'everto',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 65,
#     'char_end': 74},
#    {'token_text': 'cathedras',
#     'lemma': 'cathedra',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 75,
#     'char_end': 84}]},
#  {'work_id': '16855',
#   'sent_id': 3,
#   'sent_text': 'Nam postica latro per diverticula repit Per via gratuito pastor petit ostia gressu',
#   'tokens_data': [{'token_text': 'Nam',
#     'lemma': 'nam',
#     'pos': 'CCONJ',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 3},
#    {'token_text': 'postica',
#     'lemma': 'posticus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 4,
#     'char_end': 11},
#    {'token_text': 'latro',
#     'lemma': 'latro',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 12,
#     'char_end': 17},
#    {'token_text': 'per',
#     'lemma': 'per',
#     'pos': 'ADP',
#     'ref': '1',
#     'char_start': 18,
#     'char_end': 21},
#    {'token_text': 'diverticula',
#     'lemma': '????',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 22,
#     'char_end': 33},
#    {'token_text': 'repit',
#     'lemma': 'repo',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 34,
#     'char_end': 39},
#    {'token_text': 'Per',
#     'lemma': 'per',
#     'pos': 'ADP',
#     'ref': '1',
#     'char_start': 40,
#     'char_end': 43},
#    {'token_text': 'via',
#     'lemma': 'via',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 44,
#     'char_end': 47},
#    {'token_text': 'gratuito',
#     'lemma': 'gratuitus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 48,
#     'char_end': 56},
#    {'token_text': 'pastor',
#     'lemma': 'pastor',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 57,
#     'char_end': 63},
#    {'token_text': 'petit',
#     'lemma': 'peto',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 64,
#     'char_end': 69},
#    {'token_text': 'ostia',
#     'lemma': 'ostium',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 70,
#     'char_end': 75},
#    {'token_text': 'gressu',
#     'lemma': 'gressus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 76,
#     'char_end': 82}]},
#  {'work_id': '16855',
#   'sent_id': 4,
#   'sent_text': 'Ast ubi mangonum scelerata negotia desunt Nec grave corbanan turget venale talentum Non distractor obest quia non commercia sordent',
#   'tokens_data': [{'token_text': 'Ast',
#     'lemma': 'ast',
#     'pos': 'CCONJ',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 3},
#    {'token_text': 'ubi',
#     'lemma': 'ubi',
#     'pos': 'ADV',
#     'ref': '1',
#     'char_start': 4,
#     'char_end': 7},
#    {'token_text': 'mangonum',
#     'lemma': '????',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 8,
#     'char_end': 16},
#    {'token_text': 'scelerata',
#     'lemma': 'scelero',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 17,
#     'char_end': 26},
#    {'token_text': 'negotia',
#     'lemma': 'negotium',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 27,
#     'char_end': 34},
#    {'token_text': 'desunt',
#     'lemma': 'desum',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 35,
#     'char_end': 41},
#    {'token_text': 'Nec',
#     'lemma': 'nec',
#     'pos': 'CCONJ',
#     'ref': '1',
#     'char_start': 42,
#     'char_end': 45},
#    {'token_text': 'grave',
#     'lemma': 'gravis',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 46,
#     'char_end': 51},
#    {'token_text': 'corbanan',
#     'lemma': '????',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 52,
#     'char_end': 60},
#    {'token_text': 'turget',
#     'lemma': 'turgeo',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 61,
#     'char_end': 67},
#    {'token_text': 'venale',
#     'lemma': 'venalis',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 68,
#     'char_end': 74},
#    {'token_text': 'talentum',
#     'lemma': 'talentum',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 75,
#     'char_end': 83},
#    {'token_text': 'Non',
#     'lemma': 'Non.',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 84,
#     'char_end': 87},
#    {'token_text': 'distractor',
#     'lemma': '????',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 88,
#     'char_end': 98},
#    {'token_text': 'obest',
#     'lemma': 'obsum',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 99,
#     'char_end': 104},
#    {'token_text': 'quia',
#     'lemma': 'quia',
#     'pos': 'SCONJ',
#     'ref': '1',
#     'char_start': 105,
#     'char_end': 109},
#    {'token_text': 'non',
#     'lemma': 'non',
#     'pos': 'ADV',
#     'ref': '1',
#     'char_start': 110,
#     'char_end': 113},
#    {'token_text': 'commercia',
#     'lemma': 'commercium',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 114,
#     'char_end': 123},
#    {'token_text': 'sordent',
#     'lemma': 'sordeo',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 124,
#     'char_end': 131}]},
#  {'work_id': '16855',
#   'sent_id': 5,
#   'sent_text': 'Nam quid nummati nequeunt ubi laedere nummi',
#   'tokens_data': [{'token_text': 'Nam',
#     'lemma': 'nam',
#     'pos': 'CCONJ',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 3},
#    {'token_text': 'quid',
#     'lemma': 'quis',
#     'pos': 'PRON',
#     'ref': '1',
#     'char_start': 4,
#     'char_end': 8},
#    {'token_text': 'nummati',
#     'lemma': 'nummatus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 9,
#     'char_end': 16},
#    {'token_text': 'nequeunt',
#     'lemma': 'nequeo',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 17,
#     'char_end': 25},
#    {'token_text': 'ubi',
#     'lemma': 'ubi',
#     'pos': 'ADV',
#     'ref': '1',
#     'char_start': 26,
#     'char_end': 29},
#    {'token_text': 'laedere',
#     'lemma': 'laedo',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 30,
#     'char_end': 37},
#    {'token_text': 'nummi',
#     'lemma': 'nummus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 38,
#     'char_end': 43}]},
#  {'work_id': '16855',
#   'sent_id': 6,
#   'sent_text': 'Immo quid arboreis manus obsit squalida plantis',
#   'tokens_data': [{'token_text': 'Immo',
#     'lemma': 'immo',
#     'pos': 'ADV',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 4},
#    {'token_text': 'quid',
#     'lemma': 'quis',
#     'pos': 'PRON',
#     'ref': '1',
#     'char_start': 5,
#     'char_end': 9},
#    {'token_text': 'arboreis',
#     'lemma': 'arboreus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 10,
#     'char_end': 18},
#    {'token_text': 'manus',
#     'lemma': 'manus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 19,
#     'char_end': 24},
#    {'token_text': 'obsit',
#     'lemma': 'obsum',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 25,
#     'char_end': 30},
#    {'token_text': 'squalida',
#     'lemma': 'squalidus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 31,
#     'char_end': 39},
#    {'token_text': 'plantis',
#     'lemma': 'planta',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 40,
#     'char_end': 47}]},
#  {'work_id': '16855',
#   'sent_id': 7,
#   'sent_text': 'Sepe salutiferam medicus dedit aeger orizam Mancipites pugilem caeci genuere videntem Clenica procerum peperit male foeda venustum Nec soboles noxis est addicenda paternis',
#   'tokens_data': [{'token_text': 'Sepe',
#     'lemma': 'sepes',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 4},
#    {'token_text': 'salutiferam',
#     'lemma': 'salutifer',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 5,
#     'char_end': 16},
#    {'token_text': 'medicus',
#     'lemma': 'medicus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 17,
#     'char_end': 24},
#    {'token_text': 'dedit',
#     'lemma': 'dedo|do',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 25,
#     'char_end': 30},
#    {'token_text': 'aeger',
#     'lemma': 'aeger',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 31,
#     'char_end': 36},
#    {'token_text': 'orizam',
#     'lemma': '????',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 37,
#     'char_end': 43},
#    {'token_text': 'Mancipites',
#     'lemma': '????',
#     'pos': 'PROPN',
#     'ref': '1',
#     'char_start': 44,
#     'char_end': 54},
#    {'token_text': 'pugilem',
#     'lemma': 'pugil',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 55,
#     'char_end': 62},
#    {'token_text': 'caeci',
#     'lemma': 'caecus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 63,
#     'char_end': 68},
#    {'token_text': 'genuere',
#     'lemma': 'gigno',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 69,
#     'char_end': 76},
#    {'token_text': 'videntem',
#     'lemma': 'video',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 77,
#     'char_end': 85},
#    {'token_text': 'Clenica',
#     'lemma': '????',
#     'pos': 'PROPN',
#     'ref': '1',
#     'char_start': 86,
#     'char_end': 93},
#    {'token_text': 'procerum',
#     'lemma': 'procerus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 94,
#     'char_end': 102},
#    {'token_text': 'peperit',
#     'lemma': 'pario',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 103,
#     'char_end': 110},
#    {'token_text': 'male',
#     'lemma': 'male',
#     'pos': 'ADV',
#     'ref': '1',
#     'char_start': 111,
#     'char_end': 115},
#    {'token_text': 'foeda',
#     'lemma': 'foedus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 116,
#     'char_end': 121},
#    {'token_text': 'venustum',
#     'lemma': 'venustus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 122,
#     'char_end': 130},
#    {'token_text': 'Nec',
#     'lemma': 'nec',
#     'pos': 'CCONJ',
#     'ref': '1',
#     'char_start': 131,
#     'char_end': 134},
#    {'token_text': 'soboles',
#     'lemma': 'soboles',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 135,
#     'char_end': 142},
#    {'token_text': 'noxis',
#     'lemma': 'noxa',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 143,
#     'char_end': 148},
#    {'token_text': 'est',
#     'lemma': 'sum',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 149,
#     'char_end': 152},
#    {'token_text': 'addicenda',
#     'lemma': 'addico',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 153,
#     'char_end': 162},
#    {'token_text': 'paternis',
#     'lemma': 'paternus',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 163,
#     'char_end': 171}]},
#  {'work_id': '16855',
#   'sent_id': 8,
#   'sent_text': 'Quisque sua premitur socii nec labe tenetur',
#   'tokens_data': [{'token_text': 'Quisque',
#     'lemma': 'quisque',
#     'pos': 'X',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 7},
#    {'token_text': 'sua',
#     'lemma': 'suus',
#     'pos': 'PRON',
#     'ref': '1',
#     'char_start': 8,
#     'char_end': 11},
#    {'token_text': 'premitur',
#     'lemma': 'premo',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 12,
#     'char_end': 20},
#    {'token_text': 'socii',
#     'lemma': 'socius',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 21,
#     'char_end': 26},
#    {'token_text': 'nec',
#     'lemma': 'nec',
#     'pos': 'CCONJ',
#     'ref': '1',
#     'char_start': 27,
#     'char_end': 30},
#    {'token_text': 'labe',
#     'lemma': 'labes',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 31,
#     'char_end': 35},
#    {'token_text': 'tenetur',
#     'lemma': 'teneo',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 36,
#     'char_end': 43}]},
#  {'work_id': '16855',
#   'sent_id': 9,
#   'sent_text': 'Liber Petri Damiani Humilis Monachi Qui Appellatur Gratissimus Heinrico Ravennati Archiepiscopo Missus',
#   'tokens_data': [{'token_text': 'LIBER',
#     'lemma': 'liber',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 0,
#     'char_end': 5},
#    {'token_text': 'PETRI',
#     'lemma': 'Petrus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 6,
#     'char_end': 11},
#    {'token_text': 'DAMIANI',
#     'lemma': 'Damianus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 12,
#     'char_end': 19},
#    {'token_text': 'HUMILIS',
#     'lemma': 'humilis',
#     'pos': 'ADJ',
#     'ref': '1',
#     'char_start': 20,
#     'char_end': 27},
#    {'token_text': 'MONACHI',
#     'lemma': 'monachus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 28,
#     'char_end': 35},
#    {'token_text': 'QUI',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': '1',
#     'char_start': 36,
#     'char_end': 39},
#    {'token_text': 'APPELLATUR',
#     'lemma': 'appello',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 40,
#     'char_end': 50},
#    {'token_text': 'GRATISSIMUS',
#     'lemma': '????',
#     'pos': 'PROPN',
#     'ref': '1',
#     'char_start': 51,
#     'char_end': 62},
#    {'token_text': 'HEINRICO',
#     'lemma': '????',
#     'pos': 'PROPN',
#     'ref': '1',
#     'char_start': 63,
#     'char_end': 71},
#    {'token_text': 'RAVENNATI',
#     'lemma': '????',
#     'pos': 'PROPN',
#     'ref': '1',
#     'char_start': 72,
#     'char_end': 81},
#    {'token_text': 'ARCHIEPISCOPO',
#     'lemma': 'archiepiscopus',
#     'pos': 'NOUN',
#     'ref': '1',
#     'char_start': 82,
#     'char_end': 95},
#    {'token_text': 'MISSUS',
#     'lemma': 'mitto',
#     'pos': 'VERB',
#     'ref': '1',
#     'char_start': 96,
#     'char_end': 102}]}]

# %%
def parse_lemmatized_cc(filename):
    from bs4 import NavigableString

    with open(filename, "r", encoding="utf-8") as f:
        soup = BeautifulSoup(f, "xml")

    grela_id = os.path.splitext(os.path.basename(filename))[0]
    sentences = []
    tokens = []
    position = 0

    for div in soup.find_all("div", attrs={"cc:pid": True}):
        subwork_id = div.get("cc:pid").split(":", 1)[1] if ":" in div.get("cc:pid") else None

        for s_elem in div.find_all("cc:s", recursive=True):
            if not s_elem.get("n") or not s_elem.get("parent_pid"):
                continue

            sentence_tokens = []
            token_data = []
            char_index = 0

            for w in s_elem.find_all("cc:w"):
                token_text = w.text.strip()
                if not token_text:
                    continue

                lemma = re.sub(r"\d+$", "", w.get("lemma") or "")
                pos = map_cc_pos(w.get("pos"), token_text)

                start = char_index
                end = start + len(token_text)
                char_index = end + 1

                token_data.append({
                    "sentence_id": f"{grela_id}_{position}",
                    "grela_id": grela_id,
                    "token_text": token_text,
                    "lemma": lemma,
                    "pos": pos,
                    "char_start": start,
                    "char_end": end
                })

                sentence_tokens.append(token_text)
            sentence_tokens = [t[0] + t[1:].lower() if len(t) > 2 else t for t in sentence_tokens if t is not None and t != ""]
            if sentence_tokens:
                sentences.append({
                    "sentence_id": f"{grela_id}_{position}",
                    "grela_id": grela_id,
                    "position": position,
                    "text": " ".join(sentence_tokens),
                    "subwork_id": subwork_id
                })
                tokens.extend(token_data)
                position += 1

    return sentences, tokens

# %%
sentences, tokens = parse_lemmatized_cc("../data/cc_lemmatized_xmls/cc_10265.xml")

# %%
sentences
# Out:
# [{'sentence_id': 'cc_10265_0',
#   'grela_id': 'cc_10265',
#   'position': 0,
#   'text': 'Registri Liber Primus',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_1',
#   'grela_id': 'cc_10265',
#   'position': 1,
#   'text': 'Epistola Prima',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_2',
#   'grela_id': 'cc_10265',
#   'position': 2,
#   'text': 'AD Desiderium Abbatem',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_3',
#   'grela_id': 'cc_10265',
#   'position': 3,
#   'text': 'Nuntiat se invitum in demortui Alexandri pontificis locum suffectum',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_4',
#   'grela_id': 'cc_10265',
#   'position': 4,
#   'text': 'Rogat ut Deum pro se deprecetur et ad se quantocius veniat',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_5',
#   'grela_id': 'cc_10265',
#   'position': 5,
#   'text': 'Gregorius in Romanum pontificem electus Desiderio abbati monasterii Sancti Benedicti Montis Cassini salutem in Christo Jesu',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_6',
#   'grela_id': 'cc_10265',
#   'position': 6,
#   'text': 'Dominus noster papa Alexander mortuus est cujus mors super me cecidit et omnia viscera mea concutiens penitus conturbavit',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_7',
#   'grela_id': 'cc_10265',
#   'position': 7,
#   'text': 'Nam in morte quidem ejus Romanus populus contra morem ita quievit in manu nostra consilii frena dimisit ut evidenter appareret ex Dei misericordia hoc provenisse',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_8',
#   'grela_id': 'cc_10265',
#   'position': 8,
#   'text': 'Unde accepto consilio hoc statuimus ut post triduanum jejunium post litanias et multorum orationem eleemosynis conditam divino fulti auxilio statueremus quod melius de electione Romani pontificis videretur',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_9',
#   'grela_id': 'cc_10265',
#   'position': 9,
#   'text': 'Sed subito cum praedictus dominus noster papa in ecclesia Ad',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_10',
#   'grela_id': 'cc_10265',
#   'position': 10,
#   'text': 'Sancti sic ubique Salvatoris sepulturae traderetur ortus est magnus tumultus populi et fremitus et in me quasi vesani insurrexerunt ita ut cum Propheta possim dicere Veni in altitudinem maris et tempestas demersit me',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_11',
#   'grela_id': 'cc_10265',
#   'position': 11,
#   'text': 'Laboravi clamans raucae factae sunt fauces meae et Timor et tremor venerunt super me et contexerunt me tenebrae',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_12',
#   'grela_id': 'cc_10265',
#   'position': 12,
#   'text': 'Sed quia in lecto jacens valde fatigatus satis dictare nequeo angustias meas enarrare supersedeo',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_13',
#   'grela_id': 'cc_10265',
#   'position': 13,
#   'text': 'Te itaque per omnipotentem Dominum rogo ut suffraganeos fratres et filios quos in Christo nutris ad exorandum Deum pro me provoces et ex vera charitate invites quatenus oratio quae me liberare debuit ne incurrerem periculum saltem tueatur in periculo positum',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_14',
#   'grela_id': 'cc_10265',
#   'position': 14,
#   'text': 'Tu autem ipse quantocius ad nos venire non praetermittas qui quantum Romana Ecclesia te indigeat et in prudentia tua fiduciam habeat non ignoras',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_15',
#   'grela_id': 'cc_10265',
#   'position': 15,
#   'text': 'Dominam Agnetem imperatricem et Rainaldum venerabilem Cumanum episcopum ex nostra parte saluta et quantum erga nos dilectionis habuerint nunc Data Datum et sic semper Romae XI IX ostendant nostra vice fideliter obsecra',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_16',
#   'grela_id': 'cc_10265',
#   'position': 16,
#   'text': 'Data Datum et sic semper Romae XI IX',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_17',
#   'grela_id': 'cc_10265',
#   'position': 17,
#   'text': 'Kalendas Maii indictione XI',
#   'subwork_id': '1'},
#  {'sentence_id': 'cc_10265_18',
#   'grela_id': 'cc_10265',
#   'position': 18,
#   'text': 'Epistola II',
#   'subwork_id': '2'},
#  {'sentence_id': 'cc_10265_19',
#   'grela_id': 'cc_10265',
#   'position': 19,
#   'text': 'AD Gisulfum Principem Salernitanum',
#   'subwork_id': '2'},
#  {'sentence_id': 'cc_10265_20',
#   'grela_id': 'cc_10265',
#   'position': 20,
#   'text': 'Anno 1073',
#   'subwork_id': '2'},
#  {'sentence_id': 'cc_10265_21',
#   'grela_id': 'cc_10265',
#   'position': 21,
#   'text': 'Ejusdem argumenti',
#   'subwork_id': '2'},
#  {'sentence_id': 'cc_10265_22',
#   'grela_id': 'cc_10265',
#   'position': 22,
#   'text': 'Gregorius in Romanum pontificem electus Gisulfo Salernitano principi salutem in Christo Jesu',
#   'subwork_id': '2'},
#  {'sentence_id': 'cc_10265_23',
#   'grela_id': 'cc_10265',
#   'position': 23,
#   'text': 'Dominus noster Alexander papa mortuus est cujus mors super me cecidit',
#   'subwork_id': '2'},
#  {'sentence_id': 'cc_10265_24',
#   'grela_id': 'cc_10265',
#   'position': 24,
#   'text': 'Omnia ut supra usque ad id quod ait Te itaque per omnipotentem Dominum rogo ut venerabilem Patrem Leonem et caeteros religiosos viros in partibus illis commorantes ad exorandum Deum pro me ex vera charitate invites ut oratio quae me liberare debuit ne incurrerem periculum saltem tueatur in periculo positum',
#   'subwork_id': '2'},
#  {'sentence_id': 'cc_10265_25',
#   'grela_id': 'cc_10265',
#   'position': 25,
#   'text': 'Tu autem ipse quantocius ad nos venire non praetermittas qui quantum Romana Ecclesia te indigeat et in prudentia tua fiduciam habeat non ignoras',
#   'subwork_id': '2'},
#  {'sentence_id': 'cc_10265_26',
#   'grela_id': 'cc_10265',
#   'position': 26,
#   'text': 'Data Romae XI Viii Kalendas Maii indictione undecima',
#   'subwork_id': '2'},
#  {'sentence_id': 'cc_10265_27',
#   'grela_id': 'cc_10265',
#   'position': 27,
#   'text': 'Epistola Iii',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_28',
#   'grela_id': 'cc_10265',
#   'position': 28,
#   'text': 'AD Guibertum Ravennatem Archiepiscopum',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_29',
#   'grela_id': 'cc_10265',
#   'position': 29,
#   'text': 'Ejusdem argumenti rogat etiam ut legatos mittat',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_30',
#   'grela_id': 'cc_10265',
#   'position': 30,
#   'text': 'Gregorius in Romanum pontificem electus Guiberto Ravennati archiepiscopo salutem in Christo Jesu',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_31',
#   'grela_id': 'cc_10265',
#   'position': 31,
#   'text': 'Non dubitamus famam litteras nostras antevelasse et tam vobis quam multis aliis domini nostri Alexandri papae obitum nuntiasse',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_32',
#   'grela_id': 'cc_10265',
#   'position': 32,
#   'text': 'Quod autem mihi valde gemendum est mors ejus super me cecidit et omnia viscera mea concutiens penitus conturbavit',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_33',
#   'grela_id': 'cc_10265',
#   'position': 33,
#   'text': 'Nam in morte ejus primo quidem Romanus populus contra morem ita quievit et in manu nostra consilii frena dimisit ut evidenter appareret ex Dei misericordia hoc provenisse',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_34',
#   'grela_id': 'cc_10265',
#   'position': 34,
#   'text': 'Unde accepto consilio hoc statuimus ut post triduanum jejunium post litanias et multorum orationem eleemosynis conditam divino fulti auxilio statueremus quod de electione Romani pontificis videretur melius',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_35',
#   'grela_id': 'cc_10265',
#   'position': 35,
#   'text': 'Sed subito cum praedictus dominus noster papa in ecclesia Sancti Salvatoris sepulturae traderetur ortus est magnus tumultus populi et fremitus et in me quasi vesani insurrexerunt nil dicendi nil consulendi facultatis aut spatii relinquentes',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_36',
#   'grela_id': 'cc_10265',
#   'position': 36,
#   'text': 'Violentis manibus me in locum apostolici regiminis cui longe impar sum rapuerunt',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_37',
#   'grela_id': 'cc_10265',
#   'position': 37,
#   'text': 'Ita recte ego cum propheta possum dicere Veni in altitudinem maris et tempestas demersit me laboravi clamans raucae factae sunt fauces meae',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_38',
#   'grela_id': 'cc_10265',
#   'position': 38,
#   'text': 'Denique timor et tremor venerunt super me et contexerunt me tenebrae',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_39',
#   'grela_id': 'cc_10265',
#   'position': 39,
#   'text': 'Sed quia multis et magnis curis fatigatus satis dictare nequeo miserias meas enumerare supersedeo',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_40',
#   'grela_id': 'cc_10265',
#   'position': 40,
#   'text': 'Rogo itaque vos per omnipotentem Deum ut charitatem quam erga Romanam Ecclesiam maxime hoc tempore et ut meminisse debetis erga me specialiter vos gerere promisistis quoniam quidem tempus et rerum qualitas ejus eam probari postulat nunc quidem in me et si non meis meritis saltem amore apostolorum ostendere curetis et suffraganeos ac filios Ecclesiae vestrae ad exorandum Deum pro me invitetis ac commoneatis quatenus ad ferendum onus quod mihi invito et valde reluctanti impositum est vires tribuat manum porrigat ut si me totum forte tutum',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_41',
#   'grela_id': 'cc_10265',
#   'position': 41,
#   'text': 'Hard Ita et Mutinen',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_42',
#   'grela_id': 'cc_10265',
#   'position': 42,
#   'text': 'in portu stare noluit saltem in tam alta pericula projectum non relinquat ego enim sicut in ea charitate non ficta vos diligo ita eamdem et quaecunque ejus officia sunt a vobis indubitanter exigo',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_43',
#   'grela_id': 'cc_10265',
#   'position': 43,
#   'text': 'Neque vero dilectioni vestrae dubitandum est quin Romanam Ecclesiam et eam cui Deo auctore praesidetis ea concordia et quantum cum communi utriusque honore poterimus omnimoda charitate copulare desideremus ut in nostris etiam animis semper conjuncta pax et plena dilectio connectatur',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_44',
#   'grela_id': 'cc_10265',
#   'position': 44,
#   'text': 'Sicut igitur prudentiam vestram hortati sumus ita etiam per elementa nostra nos velle ac desiderare cognoscite videlicet ut frequenter inter nos legatis discurrentibus collaetari et mutua consolatione gaudere possimus',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_45',
#   'grela_id': 'cc_10265',
#   'position': 45,
#   'text': 'Data Romae VI Kalendas Maii indictione undecima',
#   'subwork_id': '3'},
#  {'sentence_id': 'cc_10265_46',
#   'grela_id': 'cc_10265',
#   'position': 46,
#   'text': 'Epistola IV',
#   'subwork_id': '4'},
#  {'sentence_id': 'cc_10265_47',
#   'grela_id': 'cc_10265',
#   'position': 47,
#   'text': 'AD Beatricem Ducissam Ugonem etc. Anno 1073',
#   'subwork_id': '4'},
#  {'sentence_id': 'cc_10265_48',
#   'grela_id': 'cc_10265',
#   'position': 48,
#   'text': 'Gregorius in Romanum pontificem electus Beatrici ducissae duci Ugoni abbati Cluniacensi Manassae archiepiscopo Remensi Ad',
#   'subwork_id': '4'},
#  {'sentence_id': 'cc_10265_49',
#   'grela_id': 'cc_10265',
#   'position': 49,
#   'text': 'Suenoni regi Danorum abbati Massiliensi',
#   'subwork_id': '4'},
#  {'sentence_id': 'cc_10265_50',
#   'grela_id': 'cc_10265',
#   'position': 50,
#   'text': 'Incoeptis in caeteris quidem a paribus sed circa finem singulis epistolis juxta locorum et personarum competentiam discrepantibus',
#   'subwork_id': '4'},
#  {'sentence_id': 'cc_10265_51',
#   'grela_id': 'cc_10265',
#   'position': 51,
#   'text': 'Data Romae IV Kalendas Maii indictione undecima',
#   'subwork_id': '4'},
#  {'sentence_id': 'cc_10265_52',
#   'grela_id': 'cc_10265',
#   'position': 52,
#   'text': 'Epistola V. AD Rainerium Florentinum Episcopum',
#   'subwork_id': '5'},
#  {'sentence_id': 'cc_10265_53',
#   'grela_id': 'cc_10265',
#   'position': 53,
#   'text': 'Praecipit ut vidua quae consanguineo suo nupserat donis et dote ab eo relictis privetur',
#   'subwork_id': '5'},
#  {'sentence_id': 'cc_10265_54',
#   'grela_id': 'cc_10265',
#   'position': 54,
#   'text': 'Gregorius in Romanum pontificem electus Rainerio Florentino episcopo salutem in Christo Jesu',
#   'subwork_id': '5'},
#  {'sentence_id': 'cc_10265_55',
#   'grela_id': 'cc_10265',
#   'position': 55,
#   'text': 'Praesentium portitor apicum nostris insinuavit auribus fratrem suum contra divinum jus contra sanctorum Patrum institutum consanguineae suae thalamis adhaesisse canonicis Florentinae Ecclesiae ne hoc facinus perpetraret prohibentibus eum canonice',
#   'subwork_id': '5'},
#  {'sentence_id': 'cc_10265_56',
#   'grela_id': 'cc_10265',
#   'position': 56,
#   'text': 'Quo viam universae carnis ingresso relicta illius consanguinea scilicet cum dono atque dote quam injuria divinarum nec non et humanarum legum non est verita suscipere ad alterius viri torum disponit transmigrare eum potius scelus quod commisit perpetuo oporteret eam flere',
#   'subwork_id': '5'},
#  {'sentence_id': 'cc_10265_57',
#   'grela_id': 'cc_10265',
#   'position': 57,
#   'text': 'Tua itaque fraternitas consanguinitatis lineam a majoribus natu ejusdem loci diligenter inquirat quam si inter defunctum virum eamdemque vivam mulierem invenerit ad aliarum exemplum ita studeat canonica auctoritate omnia dotalia instrumenta cassare et ad nihilum redigere ne de illicito quod contraxit conjugio aliquam mercedem recipiat qua laetari possit in posterum',
#   'subwork_id': '5'},
#  {'sentence_id': 'cc_10265_58',
#   'grela_id': 'cc_10265',
#   'position': 58,
#   'text': 'Sicut nos diligis ita nostrae jussionis primitias ad effectum perducere tua ne insistat charitas',
#   'subwork_id': '5'},
#  {'sentence_id': 'cc_10265_59',
#   'grela_id': 'cc_10265',
#   'position': 59,
#   'text': 'Data Romae Iii Kalendas Maii indictione undecima',
#   'subwork_id': '5'},
#  {'sentence_id': 'cc_10265_60',
#   'grela_id': 'cc_10265',
#   'position': 60,
#   'text': 'Epistola VI AD Giraldum Ostiensem Episcopum ET Raimbaldum Subdiaconum',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_61',
#   'grela_id': 'cc_10265',
#   'position': 61,
#   'text': 'Legatum mittit qui eis Alexandri obitum et suam electionem narret',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_62',
#   'grela_id': 'cc_10265',
#   'position': 62,
#   'text': 'Monet ut monachos et abbatem Cluniacensem ad pacem flectant',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_63',
#   'grela_id': 'cc_10265',
#   'position': 63,
#   'text': 'Et si comes de Rocyo Roceio sicut ipse jusserat in Hispaniam non fuerit contra paganos profectus vel si alii principes illuc contra eosdem proficisci velint legatus a se missus illuc tendat',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_64',
#   'grela_id': 'cc_10265',
#   'position': 64,
#   'text': 'Tandem monet ut quamprimum redeant',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_65',
#   'grela_id': 'cc_10265',
#   'position': 65,
#   'text': 'Gregorius in Romanum pontificem electus Giraldo Ostieni episcopo et Raimbaldo subdiacono in legatione Galliae constitutis salutem in Domino Jesu Christo',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_66',
#   'grela_id': 'cc_10265',
#   'position': 66,
#   'text': 'Rumorem obitus domini nostri Alexandri papae qui XI Kalendas Maii spiritum Deo reddidit et nostrae promotionis famam jam ad vos pervenisse credimus sed eadem plene vos cognoscere cupientes ad certissima eorum indicia aptiorem hoc dilecto filio et cardinali sanctae Romanae Ecclesiae presbytero qui ambolus interfuit in partes illas mittendum nostrorum nomine neminem',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_67',
#   'grela_id': 'cc_10265',
#   'position': 67,
#   'text': 'Ita et in Mutin',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_68',
#   'grela_id': 'cc_10265',
#   'position': 68,
#   'text': 'judicavimus',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_69',
#   'grela_id': 'cc_10265',
#   'position': 69,
#   'text': 'Itaque quid et qualiter de utroque factum sit per hunc mera veritate percognita ut orationes ad Deum fieri sollicite procuretis charitatem vestram valde rogamus quatenus et illius animam ad gaudia aeterna beatitudinis transferat et nobis ad ferendum onus impositum auxilium suae miserationis impendat',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_70',
#   'grela_id': 'cc_10265',
#   'position': 70,
#   'text': 'Quia vero hunc confratrem nostrum videlicet Ugonem Hugonem Candidum in partes illas dirigi tempus et rerum competentia postulasse videbatur prudentiam vestram omnino exoratam esse volumus quatenus Ugonem Hugonem Cluniacensem abbatem et totam congregationem fratrum ita ad pacem et integram hujus dilectionem flectere et conjungere studeatis ut auxiliante Deo nihil in eorum mentibus quod invisum aut dissensionis nube sit obtectum relinquatis',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_71',
#   'grela_id': 'cc_10265',
#   'position': 71,
#   'text': 'Nam et hic abjecto omni arbitrio suo ad cor nostrum nostraque consilia rediens in eodem sensu eademque voluntate ac studio nobis est connexus et ea quae antehac sibi imposita sunt vivente adhuc domino nostro papa ex aliorum magis quam ex deest ex in Rom edit ejus culpa prodiisse cognovimus',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_72',
#   'grela_id': 'cc_10265',
#   'position': 72,
#   'text': 'Praeterea haec meminisse debetis quod in litteris domini nostri beatae memoriae Alexandri et nostra quoque legatione orati et commoniti fuistis quatenus causae Evuli Eboli',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_73',
#   'grela_id': 'cc_10265',
#   'position': 73,
#   'text': 'Mutin Evoli comitis de Roceio per vos et per antedictum abbatem favorem addere insisteretis et cognita pactione quam nobiscum de terra Hispaniae pepigit in scripto quod sibi dedimus una cum consilio abbatis tales illuc personas dirigi procuraretis qui et errorem Christianorum qui ibi reperiuntur in spiritualibus corrigere saperent et in exquirendis causis Sancti Petri juxta tenorem pactionis si res bene procederet sat idonei forent',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_74',
#   'grela_id': 'cc_10265',
#   'position': 74,
#   'text': 'Quod si ita factum est nobis multum placet sin vero adhuc aliqua occasione praetermissum est aut etiam si eadem conventio ab aliis quibusdam principibus quos in eamdem partem seorsum ab Evulo suis copiis ituros intelleximus nondum exquisita est volumus ut cum vestro consilio et abbatis Hugo cardinalis illuc tendat et aequam ab omnibus ex parte Sancti Petri pactionem et debitum exigat',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_75',
#   'grela_id': 'cc_10265',
#   'position': 75,
#   'text': 'Vos autem ex nostra parte rogate abbatem ut tales sibi adjungat qui eum comitentur quorum consilio et adjutorio iter et laborem illum fiducialiter aggredi possit legatione tamen in eo principaliter posita',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_76',
#   'grela_id': 'cc_10265',
#   'position': 76,
#   'text': 'Extra Hispaniam vero nullius unquam publici rerum ecclesiasticarum negotii sine vestro consensu quandiu vos in Gallia fueritis licentiam sibi dedimus faciendi',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_77',
#   'grela_id': 'cc_10265',
#   'position': 77,
#   'text': 'Caeterum de mora vestrae reversionis valde miramur praesertim cum jam redire commoniti in tanta vestri reditus exspectatione ne morarum quidem nobis causas indicastis',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_78',
#   'grela_id': 'cc_10265',
#   'position': 78,
#   'text': 'Unde dilectionem vestram admonemus ut quantocius possitis ad nos revertamini quatenus et quid egeritis cognoscamus et de caetero consultius adjuvante Deo statuere valeamus',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_79',
#   'grela_id': 'cc_10265',
#   'position': 79,
#   'text': 'Praeter haec jam saepe memoratum abbatem specialiter commoneri et plurimum a vobis vice nostra exorari cupimus quatenus charitatem quam hactenus in nos habuit nunc cum maxime opus est indefessa exhibitione conferat et infirmitatem nostram suis et sanctissimae congregationis suae orationibus tanto subnixius adjuvare studeat quanto imbecillitatem nostram sub accumulato pondere gravius premi non ignorat',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_80',
#   'grela_id': 'cc_10265',
#   'position': 80,
#   'text': 'Data Romae secundo Kalendas Maii indictione undecima',
#   'subwork_id': '6'},
#  {'sentence_id': 'cc_10265_81',
#   'grela_id': 'cc_10265',
#   'position': 81,
#   'text': 'Epistola Vii AD Principes Hispaniae',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_82',
#   'grela_id': 'cc_10265',
#   'position': 82,
#   'text': 'Significat comiti de Roceio sub quadam conditione eam Hispaniae partem concessisse quam a Saracenorum manibus eriperet',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_83',
#   'grela_id': 'cc_10265',
#   'position': 83,
#   'text': 'Prohibet alios principes in eamdem regionem cum copiis ingredi partemque ullam illius provinciae sibi vindicare nisi interveniat aequa pactio persolvendi jura Sancti Petri qua de re legatos mittit',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_84',
#   'grela_id': 'cc_10265',
#   'position': 84,
#   'text': 'Gregorius in Romanum pontificem electus omnibus principibus in terram Hispaniae proficisci volentibus perpetuam salutem in Domino Jesu Christo',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_85',
#   'grela_id': 'cc_10265',
#   'position': 85,
#   'text': 'Non latere vos credimus regnum Hispaniae ab antiquo proprii juris Sancti Petri fuisse et adhuc licet diu a paganis sit occupatum lege tamen justitiae non evacuata nulli mortalium sed soli apostolicae sedi ex aequo pertinere',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_86',
#   'grela_id': 'cc_10265',
#   'position': 86,
#   'text': 'Quod enim auctore Deo semel in proprietatis ecclesiarum juste pervenerit manente eo ab usu quidem sed ab earum jure occasione transeuntis temporis sine legitima concessione divelli non poterit',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_87',
#   'grela_id': 'cc_10265',
#   'position': 87,
#   'text': 'Itaque comes Evulus Evolus de Roceio cujus famam apud vos haud obscuram esse putamus terram illam ad honorem sancti Petri ingredi et paganorum manibus eripere cupiens hanc concessionem ab apostolica sede obtinuit ut partem illam unde paganos suo studio et adjuncto sibi aliorum auxilio expellere posset sub conditione inter nos factae pactionis ex parte Sancti Petri possideret',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_88',
#   'grela_id': 'cc_10265',
#   'position': 88,
#   'text': 'Qua in re et labore quicunque vestrum sibi adhaerere voluerit omni charitatis affectu commonitus erga honorem sancti Petri talem animum gerat ut ab eo et munitionis auxilia in periculis et merita fidelitatis praemia securus accipiat',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_89',
#   'grela_id': 'cc_10265',
#   'position': 89,
#   'text': 'Si autem aliqui ex vobis seorsum ab illo propriis copiis eamdem terram aliqua in parte intrare paraverint decet ut militiae causam ex animi devotione quam justissimam sibi proponant jam nunc omni voto concipientes et ex corde statuentes ne capta terra easdem quas illi qui nunc Deum ignorantes eam occupant injurias sancto Petro faciant',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_90',
#   'grela_id': 'cc_10265',
#   'position': 90,
#   'text': 'Hoc enim neminem vestrum ignorare volumus quoniam nisi aequa pactione persolvendi juris Sancti Petri in regnum illud animadvertere statueritis potius vobis apostolica auctoritate ne illuc tendatis interdicendo contraferemur quam sancta et universalis mater Ecclesia idem a filiis suis quod ab hostibus patiendo non jam proprietatis suae sed filiorum detrimento saucietur',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_91',
#   'grela_id': 'cc_10265',
#   'position': 91,
#   'text': 'Quamobrem hunc dilectum filium Hugonem et cardinalem sanctae Romanae Ecclesiae presbyterum in partes illas misimus in cujus ore nostra ad vos consilia et decreta plenius apertiusque disserenda ac vice nostra disponenda posuimus',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_92',
#   'grela_id': 'cc_10265',
#   'position': 92,
#   'text': 'Data Romae II Kalendas Maii indictione undecima',
#   'subwork_id': '7'},
#  {'sentence_id': 'cc_10265_93',
#   'grela_id': 'cc_10265',
#   'position': 93,
#   'text': 'Epistola Viii AD Ubertum Clericum ET Albertum Diaconum',
#   'subwork_id': '8'},
#  {'sentence_id': 'cc_10265_94',
#   'grela_id': 'cc_10265',
#   'position': 94,
#   'text': 'Eorum legationem confirmat hortatur ut orationes pro se fieri curent',
#   'subwork_id': '8'},
#  {'sentence_id': 'cc_10265_95',
#   'grela_id': 'cc_10265',
#   'position': 95,
#   'text': 'Gregorius in Romanum pontificem electus Uberto clerico et Alberto diacono salutem in Domino Jesu Christo',
#   'subwork_id': '8'},
#  {'sentence_id': 'cc_10265_96',
#   'grela_id': 'cc_10265',
#   'position': 96,
#   'text': 'Obitum domini Alexandri papae jam vos accepisse fama nuntiante credimus et quam repente quantaque populi violentia nos indigni et reluctantes ad regimen apostolicae sedis lati forte elati',
#   'subwork_id': '8'},
#  {'sentence_id': 'cc_10265_97',
#   'grela_id': 'cc_10265',
#   'position': 97,
#   'text': 'Hard et Mutin sublati sumus',
#   'subwork_id': '8'},
#  {'sentence_id': 'cc_10265_98',
#   'grela_id': 'cc_10265',
#   'position': 98,
#   'text': 'Sed ne eventus harum rerum animos vestros in exsequenda vobis commissa legatione aut timore seu aliqua ambiguitate pertentet ad confortandam charitatem vestram haec succincte vobis scripsimus ut omnem in Deo et sancto Petro cujus filii et legati estis fiduciam habentes ad quae missi estis viriliter et incunctanter apostolica vice fulciamini et in facienda justitia fideli constantia accingamini',
#   'subwork_id': '8'},
#  {'sentence_id': 'cc_10265_99',
#   'grela_id': 'cc_10265',
#   'position': 99,
#   'text': 'Nam et ea quae a beatae memoriae domino nostro Alexandro papa injuncta vobis et commissa sunt nos quoque praesenti auctoritate injungimus firmiterque committimus in quibus peragendis ut monita damus ita auxiliante Deo apostolicae consolationis et auctoritatis subsidia vigilanti studio conferre procurabimus',
#   'subwork_id': '8'},
#  {'sentence_id': 'cc_10265_100',
#   'grela_id': 'cc_10265',
#   'position': 100,
#   'text': 'De caetero vos monemus ut in locis venerabilibus ad quos veneritis orationes pro me fieri obsecretis quatenus omnipotens Deus qui desiderium meum nunquam ad honorem istum anhelasse cognoscit ad ferendum tam grave onus quod impositum ejus timore recusare non audebam omnes facultates infirmitati meae pius impendat',
#   'subwork_id': '8'},
#  {'sentence_id': 'cc_10265_101',
#   'grela_id': 'cc_10265',
#   'position': 101,
#   'text': 'Data Romae II Kalendas Maii indictione undecima',
#   'subwork_id': '8'},
#  {'sentence_id': 'cc_10265_102',
#   'grela_id': 'cc_10265',
#   'position': 102,
#   'text': 'Epistola IX AD Gottifredum Ducem',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_103',
#   'grela_id': 'cc_10265',
#   'position': 103,
#   'text': 'Gratum sibi fuisse scribit quod litteris fuerit de sua promotione gratulatus significat tamen se dolere de suscepto pontificali munere ostendit suam erga eum et regem dilectionem optat ut rex suis monitis acquiescat',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_104',
#   'grela_id': 'cc_10265',
#   'position': 104,
#   'text': 'Gregorius in Romanum pontificem electus Gottifredo Gotefredo duci salutem in Domino Jesu Christo',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_105',
#   'grela_id': 'cc_10265',
#   'position': 105,
#   'text': 'Grata nobis est laetitia tua quam in litteris tuis de promotione nostra te habere cognovimus non ut hoc aliqua causae nostrae delectatio faciat sed quod eam ex fonte sincerae dilectionis et fideli mente derivatam esse non dubitamus',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_106',
#   'grela_id': 'cc_10265',
#   'position': 106,
#   'text': 'Nostra enim promotio quae tibi caeterisque fidelibus piam de nobis existimationem et gaudium administrat nobis interni doloris amaritudinem et nimiae anxietatis angustias generat.',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_107',
#   'grela_id': 'cc_10265',
#   'position': 107,
#   'text': 'Videmus enim quanta nos sollicitudo circumstat sentimus quantum nos suscepti oneris sarcina gravat sub quibus dum nostrae infirmitatis conscientia tremit anima nostra in Christo potius dissolutionis requiem quam in tantis periculis vitam cupit',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_108',
#   'grela_id': 'cc_10265',
#   'position': 108,
#   'text': 'In tantum quippe commissi nobis officii consideratio nos sollicitat ut nisi in orationibus spiritualium hominum post Deum aliqua fiducia nos sustentaret curarum immensitate mens nostra succumberet',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_109',
#   'grela_id': 'cc_10265',
#   'position': 109,
#   'text': 'Peccatis enim facientibus ita pene totus mundus in maligno est positus ut omnes et praecipue qui in Ecclesia praelati sunt eam potius conturbare quam fideli devotione defendere vel celebrare contendant et dum suis aut lucris aut praesentis gloriae desideriis inhiant omnibus quae ad religionem et justitiam Dei pertinent se velut hostes opponant',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_110',
#   'grela_id': 'cc_10265',
#   'position': 110,
#   'text': 'Quo magis nobis dolendum est qui susceptum universalis ecclesiae regimen in tanta difficultate nec rite administrare nec tuto deserere possumus',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_111',
#   'grela_id': 'cc_10265',
#   'position': 111,
#   'text': 'Caeterum quia fidei et constantiae virtutem donante Deo in te sitam esse cognovimus omnem quam oportet in charissimo sancti Petri filio in te fiduciam habentes animum tum de nostra idem constantissima dilectione et erga honores tuos promptissima voluntate nequaquam dubitare volumus',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_112',
#   'grela_id': 'cc_10265',
#   'position': 112,
#   'text': 'De rege vero mentem nostram et desiderium pleno cognoscere potes quod quantum in Domino sapimus neminem de ejus praesenti ac futura gloria aut sollicitiorem aut copiosiori desiderio nobis praeferri credimus',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_113',
#   'grela_id': 'cc_10265',
#   'position': 113,
#   'text': 'Est enim haec voluntas nostra ut primum oblata nobis opportunitate per nuntios nostros super his quae ad profectum Ecclesiae et honorem regiae dignitatis suae pertinere arbitramur paterna cum dilectione et admonitione conveniamus',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_114',
#   'grela_id': 'cc_10265',
#   'position': 114,
#   'text': 'Quod si nos audierit non aliter de ejus quam add de nostra salute gaudebimus quam tunc certissime sibi lucrari poterit si in tenenda justitia nostris monitis et consiliis acquieverit sin vero quod non optamus nobis odium pro dilectione omnipotenti autem Deo pro tanto honore sibi collato dissimulando justitiam ejus contemptum non ex aequo reddiderit interminatio qua dicitur Maledictus homo qui prohibet gladium suum a sanguine super nos Deo providente non veniet',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_115',
#   'grela_id': 'cc_10265',
#   'position': 115,
#   'text': 'Neque enim liberum nobis est alicujus personali gratia legem Dei postponere aut a tramite rectitudinis pro humano favore recedere dicente Apostolo Si hominibus placere vellem servus Dei non essem',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_116',
#   'grela_id': 'cc_10265',
#   'position': 116,
#   'text': 'Data Romae II Nonas Maii indictione undecima',
#   'subwork_id': '9'},
#  {'sentence_id': 'cc_10265_117',
#   'grela_id': 'cc_10265',
#   'position': 117,
#   'text': 'Epistola X. AD Guidonem Imolensem',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_118',
#   'grela_id': 'cc_10265',
#   'position': 118,
#   'text': 'Ut discordiam inter archiepiscopum Ravennatem et cives Imolenses sedet',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_119',
#   'grela_id': 'cc_10265',
#   'position': 119,
#   'text': 'Et si archiepiscopus eos a sedis apostolicae ditione conatur avellere illius auxilium praebeat donec legati illuc proficiscantur',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_120',
#   'grela_id': 'cc_10265',
#   'position': 120,
#   'text': 'Gregorius in Romanum pontificem electus Guidoni Imolensi comiti salutem in Domino Jesu Christo',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_121',
#   'grela_id': 'cc_10265',
#   'position': 121,
#   'text': 'Quidam Imolenses nostram adeuntes praesentiam conquerendo nobis indicavere quod confrater noster Guibertus Gibertus et sic semper archiepiscopus Ravennas eos contra honorem sancti Petri cui fidelitatem juravere suae omnino ditioni subigere et ad juranda sibi fidelitatis attentet sacramenta compellere',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_122',
#   'grela_id': 'cc_10265',
#   'position': 122,
#   'text': 'Verum haec relatio tanto plus admirationis nobis attulit quanto perspecta dudum in eo et fraterna charitas et sacerdotalis honestas suspicionis in illum indubitantius causas excludit',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_123',
#   'grela_id': 'cc_10265',
#   'position': 123,
#   'text': 'Neque enim credere possumus tam prudentem virum ita aut naturae aut dignitatis suae loci oblitum esse ut qui apotolorum principi fidelitatem ipse jurejurando promisit neglecto periculo suo alios qui idem fecerunt ad perjurium nitatur per exquisita ab eis sacramenta pertrahere',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_124',
#   'grela_id': 'cc_10265',
#   'position': 124,
#   'text': 'Attamen quaecunque inter eos discordia aut molestiarum sit occasio quatenus eam sedare et si possis salvo honore sancti Petri firma studeas pace decidere prudentiam tuam valde rogamus',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_125',
#   'grela_id': 'cc_10265',
#   'position': 125,
#   'text': 'Quod si aliquibus malis impedientibus non possis efficere et praedictus confrater noster archiepiscopus aut alia quaelibet persona praefatos cives a fidelitate sedis apostolicae non desinat obstinata coercitatione forte coercitione',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_126',
#   'grela_id': 'cc_10265',
#   'position': 126,
#   'text': 'II divellere sicut apostolorum tibi praesidia apud omnipotentem Deum prodesse et in hac vita non sine meritorum compendio praesidere cupis ita eis cupias ita sit praesenti auctoritate rogatus et commonitus defensionis auxilia donec legati nostri in partes illas veniant conferre non desinas',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_127',
#   'grela_id': 'cc_10265',
#   'position': 127,
#   'text': 'Nos equidem cum omnibus si fieri potest pacem habere ardenter cupimus sed eorum conatibus qui ad injuriam sancti Petri cujus servi sumus extendere se moliuntur divina adjuti tam virtute quam justitia obviare non refugimus',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_128',
#   'grela_id': 'cc_10265',
#   'position': 128,
#   'text': 'Data Romae Kalendis Junii indictione undecima',
#   'subwork_id': '10'},
#  {'sentence_id': 'cc_10265_129',
#   'grela_id': 'cc_10265',
#   'position': 129,
#   'text': 'Epistola XI',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_130',
#   'grela_id': 'cc_10265',
#   'position': 130,
#   'text': 'AD Beatricem ET Mathildem Ejus Filiam',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_131',
#   'grela_id': 'cc_10265',
#   'position': 131,
#   'text': 'Hortatur ut Simoniacos evitent',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_132',
#   'grela_id': 'cc_10265',
#   'position': 132,
#   'text': 'De Lucensi electo aliqua commemorat',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_133',
#   'grela_id': 'cc_10265',
#   'position': 133,
#   'text': 'Significat se mittere viros religiosos ad regem qui illum ad Romanam Ecclesiam revocent',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_134',
#   'grela_id': 'cc_10265',
#   'position': 134,
#   'text': 'Gregorius in Romanum pontificem electus Beatrici et ejus filiae Mathildi salutem in Domino Jesu Christo',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_135',
#   'grela_id': 'cc_10265',
#   'position': 135,
#   'text': 'Sicut beatus Gregorius in quodam super moralia Job explanationum libro ait Statutum est apud supernum judicem quanta unumquemque aut ferire adversitas aut debeat mulcere prosperitas',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_136',
#   'grela_id': 'cc_10265',
#   'position': 136,
#   'text': 'Quicunque ergo sive spe hujus vel timore illius in tempore tentationis ab his quae recta sunt deviat nec sperare in Deum nec divinarum eloquiis Scripturarum se adhaerere manifestat',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_137',
#   'grela_id': 'cc_10265',
#   'position': 137,
#   'text': 'Hoc autem ideo dicimus quia nobis et vobis imo omnibus qui confortes adoptionis filiorum Dei esse cupimus non tam occasiones nostrae existimationis videlicet quid hinc prosit inde noceat intuendae sunt quam illud ut justitiam Dei quae nunquam beatitudinis fine carebit fortiter teneamus sollicite pensandum et enitendum est',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_138',
#   'grela_id': 'cc_10265',
#   'position': 138,
#   'text': 'Scriptum est enim Sed et si quid patimini propter justitiam beati',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_139',
#   'grela_id': 'cc_10265',
#   'position': 139,
#   'text': 'Nostis dilectissimae sancti Petri filiae quam aperte Longobardorum episcopi Simoniacam haeresim defendere ac fovere praesumpserint cum Gotefredum Gotifredum Simoniacum et ob hoc excommunicatum atque damnatum sub specie benedictionis maledixerint et sub umbra ordinationis exsecratum haereticum constituerint',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_140',
#   'grela_id': 'cc_10265',
#   'position': 140,
#   'text': 'Nempe qui hactenus lapides et sagittas latenter contra Dominum jactarunt jam nunc ad subvertendam religionem et immobilem sanctae Romanae Ecclesiae petram concutiendam non dubie praecursores Antichristi et antiqui hostis satellites in apertum furoris sui campum prosiluerunt',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_141',
#   'grela_id': 'cc_10265',
#   'position': 141,
#   'text': 'Quibus favere vel consentire quam periculosum sit prudentia vestra inde perpendat quod beatus Gregorius dicit « Talibus non summopere obviare quid aliud est nisi fidem negare',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_142',
#   'grela_id': 'cc_10265',
#   'position': 142,
#   'text': '» Unde nobilitatem vestram hortamur et valde rogamus ut communionem illorum evitare et declinare studeat ne factionibus eorum consilia vel adjumenta praebeat',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_143',
#   'grela_id': 'cc_10265',
#   'position': 143,
#   'text': 'Neque vero in hac re aliqua hujus mundi ratio quae quidem vana transitoria et deceptiva est vos commoveat quoniam per misericordiam Dei et sancti Petri nulla vos inimicorum versutia laedere poterit si mentem vestram libera conscientia defendit',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_144',
#   'grela_id': 'cc_10265',
#   'position': 144,
#   'text': 'De electo vero Lucensi non aliud vobis respondendum esse pervidimus providimus nisi quod in eo tantam divinarum litterarum scientiam et rationem discretionis esse percepimus ut quae sinistra quae sit dextra ipse non ignoret',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_145',
#   'grela_id': 'cc_10265',
#   'position': 145,
#   'text': 'Quod si ad dexteram inclinaverit valde gaudemus sin vero quod absit ad sinistram utique dolemus sed nullius personae gratia vel favore impietati assensum dabimus',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_146',
#   'grela_id': 'cc_10265',
#   'position': 146,
#   'text': 'De rege autem ut antea in litteris nostris accepistis haec est voluntas nostra ut ad eum religiosos viros mittamus quorum admonitionibus inspirante Deo ad amorem sanctae Romanae et suae matris Ecclesiae eum revocare et ad condignam formam suscipiendi imperii instruere et expolire valeamus',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_147',
#   'grela_id': 'cc_10265',
#   'position': 147,
#   'text': 'Quod si nos quod non optamus audire comtempserit nos tamen a matre nostra Romana Ecclesia quae nos nutrivit et saepe filiorum suorum sanguine alios generavit filios custodiente Deo exorbitare nec possumus nec debemus',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_148',
#   'grela_id': 'cc_10265',
#   'position': 148,
#   'text': 'Et certe tutius nobis est defendendo veritatem pro sui ipsius salute adusque sanguinem nostrum sibi resistere quam ad explendam ejus voluntatem iniquitati consentiendo secum quod absit ad interitum ruere',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_149',
#   'grela_id': 'cc_10265',
#   'position': 149,
#   'text': 'Valete in Christo charissimae et in nostro dilectione corde tenus vos annexas esse scitote',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_150',
#   'grela_id': 'cc_10265',
#   'position': 150,
#   'text': 'Data Romae Viii Kalend',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_151',
#   'grela_id': 'cc_10265',
#   'position': 151,
#   'text': 'Junii Julii indictione undecima',
#   'subwork_id': '11'},
#  {'sentence_id': 'cc_10265_152',
#   'grela_id': 'cc_10265',
#   'position': 152,
#   'text': 'Epistola Xii',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_153',
#   'grela_id': 'cc_10265',
#   'position': 153,
#   'text': 'AD Gulielmum Papiensem Episcopum',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_154',
#   'grela_id': 'cc_10265',
#   'position': 154,
#   'text': 'Ostendit se ipsius litteris commotum bene jam de ipso existimare ut autem hanc opinionem de eo retineat rogat ipsum ut ecclesiae Romanae statuta amplectens contra ejus adversarios pro viribus certet',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_155',
#   'grela_id': 'cc_10265',
#   'position': 155,
#   'text': 'Gregorius in Romanum pontificem electus Gulielmo Papiensi episcopo salutem in Domino Jesu Christo',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_156',
#   'grela_id': 'cc_10265',
#   'position': 156,
#   'text': 'Nonnulla nobis frater de te antehac relata sunt e quibus animus noster non immerito turbari debuit sed in epistola tua longe alia cognoscentes ad meliorem opinionem et spem gaudii adducti sumus cupientes et illa vana fuisse et fidem eorum quae tua dilectio spondet operum attestatione percipere cujus rei praesens et copiosa tibi materia suppetit ut et his quae de te credenda suades exclusa dubitatione credamus et fraternitatem tuam integra charitate nobis imo sanctae Romanae Ecclesiae adstrictam fore comprobemus',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_157',
#   'grela_id': 'cc_10265',
#   'position': 157,
#   'text': 'Fiat itaque nobis indicium quam unanimi studio eadem nobiscum velle et pro libertate sanctae Ecclesiae quibus nos repugnamus toto nisu resistere paratus existas videlicet ut his qui catholicam fidem et ecclesiasticae religionis regulas conantur evertere non solum non consentire sed ea parte quae pro reverentia hujus sanctae sedis et debito perceptae fidei cultu illis contraire decrevit tuis consiliis adjutorioque suffulta pro tuis viribus te quoque repugnare ostendas',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_158',
#   'grela_id': 'cc_10265',
#   'position': 158,
#   'text': 'Hoc autem indubitanter scias quoniam si Mediolanenses catholici hujus rei testimonium de te nobis dederint ut Gotefredo excommunicato et episcopis qui ejus causa excommunicationis periculum incurrerunt prudenter obsistas et eis qui in certamine Christi sunt fideliter solatium praebeas non aurum vel argentum nec aliqua fraternitatis tuae studia vel obsequia nostrae et totius Romanae Ecclesiae charitati aeque te et causas tuas commendare et indissolubili cura annectere poterunt',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_159',
#   'grela_id': 'cc_10265',
#   'position': 159,
#   'text': 'In hoc etenim charissimum filium et fidum cooperatorem sanctae Romanae Ecclesiae potissimum te demonstrare poteris si ejus statuta quae a tramite sanctorum Patrum non recedit amplexando fortiter et defendendo tenueris',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_160',
#   'grela_id': 'cc_10265',
#   'position': 160,
#   'text': 'Quod quidem prae caeteris Longobardorum episcopis te oportet agere ut sicut apostolica et universalis Ecclesia eam cui Deo volente praeesse dignosceris speciali gratia et honore sublimavit ita cum necessitas et causarum labor exegerit in sollicitudine matris desudet acrius quae charitatis ejus et vicariae dispensationis munus sortitur opimius',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_161',
#   'grela_id': 'cc_10265',
#   'position': 161,
#   'text': 'Data Romae Iii IV Kal Julii indictione undecima',
#   'subwork_id': '12'},
#  {'sentence_id': 'cc_10265_162',
#   'grela_id': 'cc_10265',
#   'position': 162,
#   'text': 'Epistola Xiii AD Manassem Remensem Archiepiscopum',
#   'subwork_id': '13'},
#  {'sentence_id': 'cc_10265_163',
#   'grela_id': 'cc_10265',
#   'position': 163,
#   'text': 'Ne monachos Sancti Remigii amplius vexet et juxta canonicas sanctiones abbatem ibi ordinandum curet',
#   'subwork_id': '13'},
#  {'sentence_id': 'cc_10265_164',
#   'grela_id': 'cc_10265',
#   'position': 164,
#   'text': 'Gregorius episcopus servus servorum Dei Manassae Remensi archiepiscopo salutem et apostolicam benedictionem',
#   'subwork_id': '13'},
#  {'sentence_id': 'cc_10265_165',
#   'grela_id': 'cc_10265',
#   'position': 165,
#   'text': 'Si loci tui frater dilectissime dignitatem si officii debitum si statuta divinarum legum denique si eam quam sanctae Romanae Ecclesiae reverentiam et charitatem debes diligenter attenderes profecto rogatus et monita sedis apostolicae non toties apud te frustrari permitteres praesertim cum gravis culpa sit in hujusmodi causa te monitoris vocem provocasse vel exspectasse',
#   'subwork_id': '13'},
#  {'sentence_id': 'cc_10265_166',
#   'grela_id': 'cc_10265',
#   'position': 166,
#   'text': 'Nam quaecunque nobis e commissa dispensatione imminent negligere quidem ea absque periculo nostro non possumus nedum voluntate et studio confundere securum nobis esse putemus siquidem meminisse debet prudentia tua quoties dominus et praedecessor noster Alexander venerandae memoriae papa et nos tum per epistolas tum per legatos de causa monasterii Sancti Remigii rogando et hortando te admonuimus ne toties apostolicam audientiam fratrum clamoribus fatigari urgente necessitate sineres ne quemquam ibi cui sacri canones contradicerent in loco abbatis apponeres neu bona monasterii ab usu congregationis auferendo locum inopia dissipares sed talem ibi ad regimen abbatiae constitui regulariter procurares cui nec in exterioribus providendi diligentia nec in spirituali moderamine religio deesset aut scientia',
#   'subwork_id': '13'},
#  {'sentence_id': 'cc_10265_167',
#   'grela_id': 'cc_10265',
#   'position': 167,
#   'text': 'Quod cum saepe te facturum nobis per legatos tuos promiseris necdum tamen adimplere curasti sed ut multorum relatione comperimus de die in diem venerabilem locum illum asperius ac miserabilius tractas et ut detrimenta bonorum temporalium taceamus religiosas quoque fratrum personas crudeli ac contumeliosa captione coarctas',
#   'subwork_id': '13'},
#  {'sentence_id': 'cc_10265_168',
#   'grela_id': 'cc_10265',
#   'position': 168,
#   'text': 'Unde tui ipsius solertia perpendere potest quam gravis super hac re et te culpa et nos molestia mordeat quod apostolicae sedis auctoritas loco et fratribus quibus te jamdudum paternis affectibus consuluisse decuerat necdum erga te ad pacem et quietem prodesse potuit',
#   'subwork_id': '13'},
#  {'sentence_id': 'cc_10265_169',
#   'grela_id': 'cc_10265',
#   'position': 169,
#   'text': 'Tentare tamen adhuc frater dilectissime et miti oratione animum flectere destinavimus rogantes et ex parte beatorum apostolorum Petri et Pauli et nostra per eos apostolica auctoritate commonentes ut si deinceps spem in nostra fraternitate et dilectione habere volueris sine omni dilatione talem personam regulariter ibi ordinari in abbatem procures quae huic ordini et officio decenter congruat et caetera quae necessitas et justitia monasterii exigit ita corrigas et emendes ne fratrum ulterius ad nos referri querela debeat',
#   'subwork_id': '13'},
# ...
#  {'sentence_id': 'cc_10265_940',
#   'grela_id': 'cc_10265',
#   'position': 940,
#   'text': 'Cum vero Ananiam et Sapphiram propter propria bona quae beato Petro promiserant et non dederunt mortem incurrisse non ignores quo instinctu nisi diabolico tantam invasionem praesumpsisti',
#   'subwork_id': '68'},
#  {'sentence_id': 'cc_10265_941',
#   'grela_id': 'cc_10265',
#   'position': 941,
#   'text': 'tantam contumeliam intulisti',
#   'subwork_id': '68'},
#  {'sentence_id': 'cc_10265_942',
#   'grela_id': 'cc_10265',
#   'position': 942,
#   'text': 'tantum sacrilegium in apostolorum principem perpetrasti',
#   'subwork_id': '68'},
#  {'sentence_id': 'cc_10265_943',
#   'grela_id': 'cc_10265',
#   'position': 943,
#   'text': 'Quapropter apostolica tibi auctoritate praecipimus ut perspectis his apicibus absque omni occasione vel dilatione praedictam nostram Crosciensem ecclesiam expediens liberam reddas presbyteros et clericos absolutos et omnia quae inde tulisti sibi restituas et cum pace et quiete ibi Deo servire sub beati Petri ditione in tuitione nostra permittas',
#   'subwork_id': '68'},
#  {'sentence_id': 'cc_10265_944',
#   'grela_id': 'cc_10265',
#   'position': 944,
#   'text': 'Si autem te aliquam justitiam in praemissa ecclesia habere existimas ad nos cito cum praelibatis canonicis nostris venias ut justitiam in praesentia nostra recipias',
#   'subwork_id': '68'},
#  {'sentence_id': 'cc_10265_945',
#   'grela_id': 'cc_10265',
#   'position': 945,
#   'text': 'Si autem hoc non feceris te apostolica auctoritate excommunicandum noveris',
#   'subwork_id': '68'},
#  {'sentence_id': 'cc_10265_946',
#   'grela_id': 'cc_10265',
#   'position': 946,
#   'text': 'Data Romae Xii Kalendas Aprilis indictione duodecima',
#   'subwork_id': '68'},
#  {'sentence_id': 'cc_10265_947',
#   'grela_id': 'cc_10265',
#   'position': 947,
#   'text': 'Epistola Lxviii',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_948',
#   'grela_id': 'cc_10265',
#   'position': 948,
#   'text': 'AD Froterium Nemausensem Episcopum',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_949',
#   'grela_id': 'cc_10265',
#   'position': 949,
#   'text': 'Queritur de injuriis illatis monasterio Sancti Aegidii et ejus abbati contempta apostolica sede',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_950',
#   'grela_id': 'cc_10265',
#   'position': 950,
#   'text': 'Jubet ipsum desistere',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_951',
#   'grela_id': 'cc_10265',
#   'position': 951,
#   'text': 'Gregorius episcopus servus servorum Dei Froterio Nemausensi in provincia episcopo salutem et apostolicam benedictionem',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_952',
#   'grela_id': 'cc_10265',
#   'position': 952,
#   'text': 'Audivimus olim nostri tempore praedecessoris venerabilis memoriae Alexandri te contra justitiam monasterium Sancti Aegidii quod idem gloriosus confessor juri beati Petri tradidit usque adeo affecisse injuriis ut ejusdem abbatem a Romano pontifice consecratum capere praesumeres spreto rigore canonum contemptisque privilegiis ab apostolica sede derivatis',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_953',
#   'grela_id': 'cc_10265',
#   'position': 953,
#   'text': 'Unde tunc merito et adhuc dolemus non dubitantes abbatis contumelias Romanae majestati fuisse illatas',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_954',
#   'grela_id': 'cc_10265',
#   'position': 954,
#   'text': 'Nihilominus quoque nobis displicet quod quasi de integro tibi licentiam usurpas praefatum excommunicandi coenobium cum hoc tibi non licere hujus sanctae sedis auctoritas authenticorum testetur in datione privilegiorum',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_955',
#   'grela_id': 'cc_10265',
#   'position': 955,
#   'text': 'Quapropter praecipiendo rogamus et rogando praecipimus nullius etiam sub obtentu occasione justitiae sive excommunicando sive missas celebrando fratres praedicti coenibii praesumas inquietare',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_956',
#   'grela_id': 'cc_10265',
#   'position': 956,
#   'text': 'Si autem illi in aliquo tibi esse videbuntur injusti volentes ac potentes non deerimus ad faciendam tibi de ipsis justitiam',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_957',
#   'grela_id': 'cc_10265',
#   'position': 957,
#   'text': 'Sin vero quod absit nostrae exhortationis imo praecepti neglector exstiteris illos deest aliquid ut illos scias etc. autem a jugo servitutis per auctoritatem quae data est apostolo Petro nos ejusdem vicarios ut Deo libere serviant esse absolutos',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_958',
#   'grela_id': 'cc_10265',
#   'position': 958,
#   'text': 'Data Romae XI Kalendas Aprilis indictione Xii',
#   'subwork_id': '69'},
#  {'sentence_id': 'cc_10265_959',
#   'grela_id': 'cc_10265',
#   'position': 959,
#   'text': 'Epistola Lxix',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_960',
#   'grela_id': 'cc_10265',
#   'position': 960,
#   'text': 'AD Guilielmum Diensem Comitem',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_961',
#   'grela_id': 'cc_10265',
#   'position': 961,
#   'text': 'Remittit episcopum ab ipsis electum et a se consecratum jubetque eos ipsi obedire praecipue in Simoniaca haeresi exstirpanda',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_962',
#   'grela_id': 'cc_10265',
#   'position': 962,
#   'text': 'Minatur ipsi comiti excommunicationem si jus suum retribuere noluerit episcopo et ejus Ecclesiae',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_963',
#   'grela_id': 'cc_10265',
#   'position': 963,
#   'text': 'Gregorius episcopus servus servorum Dei Guilielmo Diensi comiti ac universis fidelibus ac subditis Diensis Ecclesiae salutem et apostolicam benedictionem',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_964',
#   'grela_id': 'cc_10265',
#   'position': 964,
#   'text': 'Venientem ad nos Hugonem episcopum vestrum benigne suscepimus et quia vos in electionem ejus unanimiter convenisse audivimus episcopali consecratione eum vobis in pastorem ordinavimus quatenus sub ejus regimine spiritualibus instructi disciplinis perceptae fidei fructum et gloriam sempiternam consequi Deo dante possitis',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_965',
#   'grela_id': 'cc_10265',
#   'position': 965,
#   'text': 'Expleto igitur in eo ministerii nostri debito cum omni charitate eum ad vos remittimus admonentes vos per fidem in qua redempti et per Christum salvati estis ut eum debito honore et reverentia suscipiatis et omnem in omnibus quae ad regimen sui episcopatus pertinent obedientiam et favorem sibi exhibeatis',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_966',
#   'grela_id': 'cc_10265',
#   'position': 966,
#   'text': 'Nos enim inter caetera eum sollicite admonuimus ut contra Simoniacam haeresim totis erigeretur viribus et Ecclesiam suae parochiae non prius consecraret nec consecratas aliter divinum officium celebrare permitteret nisi prius absolute a laicorum manibus sicut canonicum est suo juri et episcopali ejus providentiae redderentur',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_967',
#   'grela_id': 'cc_10265',
#   'position': 967,
#   'text': 'Quamobrem ne quis ei contrarius in exsequendo monita nostra obsistat apostolica auctoritate sub anathematis comminatione interdicimus',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_968',
#   'grela_id': 'cc_10265',
#   'position': 968,
#   'text': 'Te autem praedicte comes singulariter alloquentes valde miramur quod postquam praefatum confratrem nostrum instinctu divinae clementiae cum consensu aliorum omnium in episcopum elegeras et fidelitatem sibi ex more feceras nescio quibus de causis elatus eo praesente commotionem adversus eum agere praesumpsisti et postquam ad apostolica limina venit clericos et cives urbis depraedatus es et quod valde nefandum est quemdam clericum cepisti',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_969',
#   'grela_id': 'cc_10265',
#   'position': 969,
#   'text': 'Quamvis igitur in hac tanta et tam crudeli praesumptione censuram apostolicae animadversionis in te provocaveris rogatu tamen ejusdem episcopi tui adhuc debitae ultionis jaculum in te vibrare distulimus',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_970',
#   'grela_id': 'cc_10265',
#   'position': 970,
#   'text': 'Caeterum ne haec patientia nostra te in audaciam erigat et nos in culpam neglectae justitiae trahat apostolica te auctoritate monemus atque praecipimus ut sine omni dilatione quaecunque adversus episcopum et Ecclesiam sibi commissam temere et inique commisisti digna satisfactione emendes et ulterius nulla eum contrarietate molestare praesumas',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_971',
#   'grela_id': 'cc_10265',
#   'position': 971,
#   'text': 'Alioquin scias episcopum nostrum apostolica jussione constrictum te sicut hostem et impugnatorem justitiae a liminibus ecclesiae anathematis innodatum vinculis sequestrare',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_972',
#   'grela_id': 'cc_10265',
#   'position': 972,
#   'text': 'Quod et si ipse quod non credimus timore aliquo vel gratia praetermitteret nos tamen tantae temeritatis facinus non relinquemus forte relinqueremus inultum et episcopus pro negligentia officii sui non leve suscepti ministerii perpenderet sibi imminere periculum',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_973',
#   'grela_id': 'cc_10265',
#   'position': 973,
#   'text': 'Datum Romae decimo septimo X Kalendas Aprilis indictione duodecima',
#   'subwork_id': '70'},
#  {'sentence_id': 'cc_10265_974',
#   'grela_id': 'cc_10265',
#   'position': 974,
#   'text': 'Epistola Lxx',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_975',
#   'grela_id': 'cc_10265',
#   'position': 975,
#   'text': 'AD Guilielmum Regem Anglorum',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_976',
#   'grela_id': 'cc_10265',
#   'position': 976,
#   'text': 'Commendat Guilielmi regis erga se et apostolicam sedem observantiam hortaturque eum ad ecclesiarum defensionem significat se et Ecclesiam in magnis perturbationibus versari',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_977',
#   'grela_id': 'cc_10265',
#   'position': 977,
#   'text': 'Quoddam privilegium sancti Stephani ratum haberi consulit',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_978',
#   'grela_id': 'cc_10265',
#   'position': 978,
#   'text': 'Bona sancti Petri in Anglia commendat',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_979',
#   'grela_id': 'cc_10265',
#   'position': 979,
#   'text': 'Gregorius episcopus servus servorum Dei Guilielmo regi Anglorum salutem et apostolicam benedictionem',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_980',
#   'grela_id': 'cc_10265',
#   'position': 980,
#   'text': 'Moerore mentis tuae fili dilecte ex decessu antecessoris nostri beatae memoriae Alexandri tui etiam hilaritate ex nostrae promotionis certo rumore absque dubio credimus te ex corde matri tuae sanctae Romanae Ecclesiae adhaerere eamque totis viribus ut debes diligere',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_981',
#   'grela_id': 'cc_10265',
#   'position': 981,
#   'text': 'Nam quia ejus quasi viduitate audita graviter angebaris consolatione etiam sua de nostri promotione vero gaudio laetaris statumque nostrum te velle scire per litteras tuas obnixe et humiliter precaris',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_982',
#   'grela_id': 'cc_10265',
#   'position': 982,
#   'text': 'Affectum boni filii affectum filii matrem ex corde diligentis ostendis',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_983',
#   'grela_id': 'cc_10265',
#   'position': 983,
#   'text': 'Exsequere ergo operibus fili dilecte quod ore confiteris imple efficaciter quod dicis ut consentias ipsi Veritati clamanti Qui diligit me sermones meos servabit et alibi Probatio dilectionis exhibitio est operis',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_984',
#   'grela_id': 'cc_10265',
#   'position': 984,
#   'text': 'Sermones matris tuae hi sunt et hujusmodi Justitiae per omnia cum opportunum est tu modo insudare non desinas Ecclesiis tibi ad defendendum commissis sic consulere ut fomenta salutis animae tuae conficias peccatorum maculas deleas virtutum odores sic tibi introducas ut cum Apostolo dicas Christi bonus odor sumus',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_985',
#   'grela_id': 'cc_10265',
#   'position': 985,
#   'text': 'Honorem Dei et omnia quae Dei sunt tuo et mundanis omnibus praeponere consulimus admonemus et precamur cum hoc ex certo sit unum quod neglectum saepius tuae dignitatis potestates solet perdere et ad inferos trudere',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_986',
#   'grela_id': 'cc_10265',
#   'position': 986,
#   'text': 'Haec ideo charissime tibi inculcamus quia inter reges te solum habemus quem prae aliis diligere suprascripta credimus',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_987',
#   'grela_id': 'cc_10265',
#   'position': 987,
#   'text': 'Statum verum nostrum quem te scire suppliciter oras sic accipe Navem inviti ascendimus quae per undosum pelagus violentia ventorum et impetu turbinum et fluctibus ad aera usque insurgentibus in incerta dejicitur saxis occultatis et aliis a longe in altum apparentibus licet cum periculo obviat tamen et ex animo',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_988',
#   'grela_id': 'cc_10265',
#   'position': 988,
#   'text': 'Sancta quippe Romana Ecclesia cui licet indigni et nolentes praesidemus diversis tentationibus quamplurimis persecutionibus hypocritarum et haereticorum insidiis et dolosis objectionibus continue et quotidie quatitur mundanis vero potestatibus occulte et evidenter per diversa distrahitur',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_989',
#   'grela_id': 'cc_10265',
#   'position': 989,
#   'text': 'Quibus omnibus obviare et his et quamplurimis aliis summopere cavere post Deum et inter homines nostri et officii et curae specialiter horum cura die noctuque coquimur his et similibus continue divellimur licet pro tempore ab hujus mundi filiis haec nobis videantur arridere',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_990',
#   'grela_id': 'cc_10265',
#   'position': 990,
#   'text': 'Quae tamen grates Deo referimus mundana coguntur nobis displicere',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_991',
#   'grela_id': 'cc_10265',
#   'position': 991,
#   'text': 'Sic vivimus et Deo annuente vivemus',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_992',
#   'grela_id': 'cc_10265',
#   'position': 992,
#   'text': 'Privilegium vero sancti Stephani de quo mandasti animae tuae salus est et pro eodem tibi consulimus sic ratum te habere prout legati nostri Petrus et Joannes Minutus canonice observandum judicarunt',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_993',
#   'grela_id': 'cc_10265',
#   'position': 993,
#   'text': 'Si tamen superabundans aliquid privilegio tibi videtur adscriptum quantum plura pro Deo et sancto Petro beato Stephano concesseris tanto majora in retributione ab his procul dubio habebis',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_994',
#   'grela_id': 'cc_10265',
#   'position': 994,
#   'text': 'Rebus vero sancti Petri quae in Anglia colliguntur sic te ut tuis invigilare admonemus sic liberalitati tuae ut tua committimus ut pium et propitium debitorem Petrum reperias et eum tibi ex debito subvenire admoneas quem sibi multa te tribuisse non latebit',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_995',
#   'grela_id': 'cc_10265',
#   'position': 995,
#   'text': 'Data Romae II Nonas Aprilis indict',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_996',
#   'grela_id': 'cc_10265',
#   'position': 996,
#   'text': 'Xii',
#   'subwork_id': '71'},
#  {'sentence_id': 'cc_10265_997',
#   'grela_id': 'cc_10265',
#   'position': 997,
#   'text': 'Epistola Lxxi',
#   'subwork_id': '72'},
#  {'sentence_id': 'cc_10265_998',
#   'grela_id': 'cc_10265',
#   'position': 998,
#   'text': 'AD Mathildem Reginam Anglorum',
#   'subwork_id': '72'},
#  {'sentence_id': 'cc_10265_999',
#   'grela_id': 'cc_10265',
#   'position': 999,
#   'text': 'Commendat ejus humilitatem et charitatem hortatur ut in dies in his magis proficiat et in viro suo ea suadeat quae ad animae salutem in primis pertinent',
#   'subwork_id': '72'},
#  ...]

# %%
import os
import pandas as pd

def replace_grela_sentences_and_tokens_duckdb(xml_path):
    grela_id = os.path.splitext(os.path.basename(xml_path))[0]

    # Parse XML
    sentences, tokens = parse_lemmatized_cc(xml_path)

    if not sentences:
        raise RuntimeError(f"⚠️ No sentence data parsed from {xml_path}")
    if not tokens:
        raise RuntimeError(f"⚠️ No token data parsed from {xml_path}")

    # Convert to DataFrames
    sentences_df = pd.DataFrame(sentences)
    tokens_df = pd.DataFrame(tokens)

    # Register DataFrames for DuckDB
    conn.register("sentences_df", sentences_df)
    conn.register("tokens_df", tokens_df)

    try:
        # Delete existing entries
        conn.execute("DELETE FROM sentences WHERE grela_id = ?", (grela_id,))
        conn.execute("DELETE FROM tokens WHERE grela_id = ?", (grela_id,))

        # Insert new data from registered DataFrames
        conn.execute("""
            INSERT INTO sentences (sentence_id, grela_id, position, text, subwork_id)
            SELECT sentence_id, grela_id, position, text, subwork_id FROM sentences_df
        """)

        conn.execute("""
            INSERT INTO tokens (sentence_id, grela_id, token_text, lemma, pos, char_start, char_end)
            SELECT sentence_id, grela_id, token_text, lemma, pos, char_start, char_end FROM tokens_df
        """)

        print(f"✅ Fast update: {grela_id} → {len(sentences)} sentences, {len(tokens)} tokens.")

    except Exception as e:
        raise RuntimeError(f"❌ DuckDB update failed for {grela_id}: {e}")

# %%
query = "ALTER TABLE sentences ADD COLUMN subwork_id TEXT;"
conn.execute(query)

# %%
replace_grela_sentences_and_tokens_duckdb(
    xml_path="../data/cc_lemmatized_xmls/cc_10265.xml"
)
# Out:
# ✅ Fast update: cc_10265 → 5399 sentences, 130090 tokens.

# %%
grela_id = "cc_10265"
conn.execute(f"""
    UPDATE tokens
    SET token_id = subquery.new_id
    FROM (
        SELECT row_number() OVER () AS new_id, t.rowid AS real_rowid
        FROM tokens t
        WHERE grela_id = ?
    ) AS subquery
    WHERE tokens.rowid = subquery.real_rowid
""", (grela_id,))

# %%
register_df = conn.execute("""
    SELECT s.sentence_id, s.text, e.embedding
    FROM sentence_embeddings e
    JOIN sentences s ON e.sentence_id = s.sentence_id
    WHERE e.grela_id = 'cc_10265'
""").fetchdf()

# %%
register_df.head(5)
# Out:
#   sentence_id                                               text  \
# 0  cc_10265_0                              Registri Liber Primus
# 1  cc_10265_1                                     Epistola Prima
# 2  cc_10265_2                              AD Desiderium Abbatem
# 3  cc_10265_3  Nuntiat se invitum in demortui Alexandri ponti...
# 4  cc_10265_4  Rogat ut Deum pro se deprecetur et ad se quant...
#
#                                            embedding
# 0  [-0.0411662794649601, -0.017861537635326385, 0...
# 1  [-0.039150845259428024, 0.04118065908551216, -...
# 2  [-0.009886219166219234, -0.014916053973138332,...
# 3  [-0.008567786775529385, 0.05232088640332222, -...
# 4  [-0.0074958037585020065, -0.022528640925884247...

# %%
register_tokens_df = conn.execute("""
    SELECT t.*
    FROM tokens t
    WHERE t.grela_id = 'cc_10265'
""").fetchdf()

# %%
len(register_tokens_df)
# Out:
# 130090

# %%
register_tokens_df[:20]
# Out:
#    sentence_id  grela_id  token_text        lemma    pos  char_start  \
# 0   cc_10265_0  cc_10265    REGISTRI         ????  PROPN           0
# 1   cc_10265_0  cc_10265       LIBER        liber   NOUN           9
# 2   cc_10265_0  cc_10265      PRIMUS         unus    ADJ          15
# 3   cc_10265_1  cc_10265    EPISTOLA     epistola   NOUN           0
# 4   cc_10265_1  cc_10265       PRIMA         unus    ADJ           9
# 5   cc_10265_2  cc_10265          AD           ad    ADP           0
# 6   cc_10265_2  cc_10265  DESIDERIUM   desiderium   NOUN           3
# 7   cc_10265_2  cc_10265     ABBATEM        abbas   NOUN          14
# 8   cc_10265_3  cc_10265     Nuntiat       nuntio   VERB           0
# 9   cc_10265_3  cc_10265          se           se   PRON           8
# 10  cc_10265_3  cc_10265     invitum      invitus    ADJ          11
# 11  cc_10265_3  cc_10265          in           in    ADP          19
# 12  cc_10265_3  cc_10265    demortui    demortuus    ADJ          22
# 13  cc_10265_3  cc_10265   Alexandri    Alexander   NOUN          31
# 14  cc_10265_3  cc_10265  pontificis     pontifex   NOUN          41
# 15  cc_10265_3  cc_10265       locum  locum|locus   NOUN          52
# 16  cc_10265_3  cc_10265   suffectum            -   VERB          58
# 17  cc_10265_4  cc_10265       Rogat         rogo   VERB           0
# 18  cc_10265_4  cc_10265          ut           ut  SCONJ           6
# 19  cc_10265_4  cc_10265        Deum     Deus|dea   NOUN           9
#
#     char_end  token_id
# 0          8         1
# 1         14         2
# 2         21         3
# 3          8         4
# 4         14         5
# 5          2         6
# 6         13         7
# 7         21         8
# 8          7         9
# 9         10        10
# 10        18        11
# 11        21        12
# 12        30        13
# 13        40        14
# 14        51        15
# 15        57        16
# 16        67        17
# 17         5        18
# 18         8        19
# 19        13        20

# %%
conn.close()
