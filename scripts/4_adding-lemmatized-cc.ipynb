# %%
 import os
import re
from bs4 import BeautifulSoup, NavigableString
import json
import pandas as pd

# %%
def parse_tei_header_from_soup(soup, work_id: str) -> dict:
    """
    Extract basic TEI header metadata as a dict.

    Assumes tags are lowercase (BeautifulSoup with 'html.parser').
    """
    meta = {}

    teiheader = soup.find("teiheader")
    if not teiheader:
        return meta

    filedesc = teiheader.find("filedesc")
    if not filedesc:
        return meta

    # ----- titleStmt -----
    titlestmt = filedesc.find("titlestmt")
    if titlestmt:
        title_tag = titlestmt.find("title")
        if title_tag:
            # include nested content (e.g. <hi>, etc.)
            meta["title"] = " ".join(title_tag.stripped_strings)

        author_tag = titlestmt.find("author")
        if author_tag:
            # dates inside <author><date>...</date></author>
            date_tag = author_tag.find("date")
            if date_tag and date_tag.get_text(strip=True):
                author_dates = date_tag.get_text(strip=True)
                meta["author_dates"] = author_dates
                date_tag.extract()  # remove from author_tag so we get clean name

            author_name = author_tag.get_text(strip=True)
            if author_name:
                meta["author"] = author_name

            # VIAF link, if present
            ref = author_tag.get("ref")
            if ref:
                meta["author_viaf"] = ref
                # try to extract numeric VIAF id
                m = re.search(r"/(\d+)$", ref.strip("/"))
                if m:
                    meta["author_viaf_id"] = m.group(1)

    # ----- editionStmt -----
    editionstmt = filedesc.find("editionstmt")
    if editionstmt:
        edition_tag = editionstmt.find("edition")
        if edition_tag:
            meta["edition"] = " ".join(edition_tag.stripped_strings)

        editor_tag = editionstmt.find("editor")
        if editor_tag:
            meta["editor"] = " ".join(editor_tag.stripped_strings)

    # ----- publicationStmt -----
    publicationstmt = filedesc.find("publicationstmt")
    if publicationstmt:
        publisher_tag = publicationstmt.find("publisher")
        if publisher_tag:
            meta["publisher"] = publisher_tag.get_text(strip=True)

        pubplace_tag = publicationstmt.find("pubplace")
        if pubplace_tag:
            meta["pub_place"] = pubplace_tag.get_text(strip=True)

        date_tag = publicationstmt.find("date")
        if date_tag and date_tag.get_text(strip=True):
            meta["pub_date"] = date_tag.get_text(strip=True)

    # ----- seriesStmt -----
    seriesstmt = filedesc.find("seriesstmt")
    if seriesstmt:
        series_title_tag = seriesstmt.find("title")
        if series_title_tag:
            meta["series_title"] = " ".join(series_title_tag.stripped_strings)

        idno_tag = seriesstmt.find("idno")
        if idno_tag:
            meta["series_id"] = idno_tag.get_text(strip=True)

    # ----- notesStmt -----
    notesstmt = filedesc.find("notesstmt")
    if notesstmt:
        notes = [
            " ".join(note.stripped_strings)
            for note in notesstmt.find_all("note")
            if note.get_text(strip=True)
        ]
        if notes:
            meta["notes"] = notes

    # ----- sourceDesc -----
    sourcedesc = filedesc.find("sourcedesc")
    if sourcedesc:
        p_tag = sourcedesc.find("p")
        if p_tag:
            meta["source"] = " ".join(p_tag.stripped_strings)

    return meta

# %%
def normalize_latin(s: str) -> str:
    return s.lower().replace("v", "u").replace("j", "i")

def map_cc_pos(pos_tag, token_text):
    if pos_tag is None:
        return "X"

    if pos_tag.startswith("V:"):
        return "VERB"
    if pos_tag.startswith("N:"):
        return "NOUN"
    if pos_tag.startswith("ADJ"):
        return "ADJ"
    if pos_tag.startswith("ADV"):
        return "ADV"
    if pos_tag.startswith("PREP"):
        return "ADP"
    if pos_tag in {"CC", "CON", "CS"}:
        return "CCONJ" if pos_tag == "CC" else "SCONJ"
    if pos_tag in {"PRON", "REL", "DIMOS", "POSS", "DET"}:
        return "PRON"
    if pos_tag == "NUM" or "NUM" in pos_tag:
        return "NUM"
    # heuristic for unknown proper names etc.
    if token_text and token_text[0].isupper():
        if pos_tag.startswith("N:") or pos_tag == "????":
            return "PROPN"
    return "X"


def build_ref(div_pid, parent_pid, sent_n):
    """
    Build a generic ref dict from TEI/CC identifiers.
    This is *intentionally* vague but sentence-specific.
    """
    ref = {}
    if div_pid:
        ref["div_pid"] = div_pid            # e.g. "45:2.12"
        # Optionally split:
        # m = re.match(r"(?P<work>\d+):(?P<section>.+)", div_pid)
        # if m:
        #     ref["work_no"] = m.group("work")
        #     ref["section"] = m.group("section")
    if parent_pid:
        ref["parent_pid"] = parent_pid      # e.g. "45:2.12;2"
    if sent_n:
        ref["sent_n"] = sent_n              # e.g. "1"
    return ref

def parse_lemmatized_cc(filename):
    with open(filename, "r", encoding="utf-8") as f:
        soup = BeautifulSoup(f, "html.parser")

    work_id = os.path.splitext(os.path.basename(filename))[0]

    # NEW: parse TEI header metadata
    metadata = parse_tei_header_from_soup(soup, work_id)

    sentences = []
    position = 0

    for div in soup.find_all("div", attrs={"cc:pid": True}):
        div_pid = div.get("cc:pid")  # e.g. "45:2.12"

        for s_elem in div.find_all("cc:s", recursive=True):
            if not s_elem.get("n") or not s_elem.get("parent_pid"):
                continue

            sent_n = s_elem.get("n")
            parent_pid = s_elem.get("parent_pid")
            ref_dict = build_ref(div_pid, parent_pid, sent_n)

            sentence_tokens = []
            token_data = []
            char_index = 0

            for w in s_elem.find_all("cc:w"):
                token_text = w.text.strip()
                if not token_text:
                    continue

                raw_lemma = (w.get("lemma") or "").partition("|")[0]
                raw_lemma = re.sub(r"\d+$", "", raw_lemma)
                # your "??" rule, if you keep it:
                if raw_lemma.startswith("??"):
                    lemma = token_text.lower().replace("v", "u").replace("j", "i")
                else:
                    lemma = raw_lemma.replace("v", "u").replace("j", "i")

                pos = map_cc_pos(w.get("pos"), token_text)

                start = char_index
                end = start + len(token_text)
                char_index = end + 1

                token_data.append({
                    "token_text": token_text,
                    "lemma": lemma,
                    "pos": pos,
                    "ref": ref_dict,
                    "char_start": start,
                    "char_end": end
                })
                sentence_tokens.append(token_text)

            sentence_tokens = [
                t[0] + t[1:].lower() if len(t) > 2 else t
                for t in sentence_tokens
                if t
            ]

            if sentence_tokens:
                sentences.append({
                    "work_id": work_id,
                    "sent_id": position,
                    "sent_text": " ".join(sentence_tokens),
                    "token_data": token_data
                })
                position += 1

    # Return both: metadata for the work, and the sentence list
    metadata["work_id"] = work_id
    metadata["prelemmatized"] = True
    return metadata, sentences

# %%
source_path = "../data/large_data/lemmatized-xmls/"
os.listdir(source_path)[:10]
# Out:
# ['8209.xml',
#  '11823.xml',
#  '9537.xml',
#  '12666.xml',
#  '11811.xml',
#  '14817.xml',
#  '11332.xml',
#  '52.xml',
#  '7160.xml',
#  '14403.xml']

# %%
filename = os.listdir(source_path)[7000]
metadata, sentences = parse_lemmatized_cc(os.path.join(source_path, filename))

# %%
sentences[:10]
# Out:
# [{'work_id': '10339',
#   'sent_id': 0,
#   'sent_text': 'Praefatio in canonum collectionem',
#   'token_data': [{'token_text': 'Praefatio',
#     'lemma': 'praefatio',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;1', 'sent_n': '1'},
#     'char_start': 0,
#     'char_end': 9},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;1', 'sent_n': '1'},
#     'char_start': 10,
#     'char_end': 12},
#    {'token_text': 'canonum',
#     'lemma': 'canon',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;1', 'sent_n': '1'},
#     'char_start': 13,
#     'char_end': 20},
#    {'token_text': 'collectionem',
#     'lemma': 'collectio',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;1', 'sent_n': '1'},
#     'char_start': 21,
#     'char_end': 33}]},
#  {'work_id': '10339',
#   'sent_id': 1,
#   'sent_text': 'Beatissimo atque apostolico viro pontifici domno papae Victori tertio et omni clero sanctae Romanae Ecclesiae Deusdedit exiguus presbyter tituli Apostolorum in Eudoxia',
#   'token_data': [{'token_text': 'Beatissimo',
#     'lemma': 'beatus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 0,
#     'char_end': 10},
#    {'token_text': 'atque',
#     'lemma': 'atque',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 11,
#     'char_end': 16},
#    {'token_text': 'apostolico',
#     'lemma': 'apostolicus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 17,
#     'char_end': 27},
#    {'token_text': 'viro',
#     'lemma': 'uir',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 28,
#     'char_end': 32},
#    {'token_text': 'pontifici',
#     'lemma': 'pontifex',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 33,
#     'char_end': 42},
#    {'token_text': 'domno',
#     'lemma': 'domnus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 43,
#     'char_end': 48},
#    {'token_text': 'papae',
#     'lemma': 'Papa',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 49,
#     'char_end': 54},
#    {'token_text': 'Victori',
#     'lemma': 'uictor',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 55,
#     'char_end': 62},
#    {'token_text': 'tertio',
#     'lemma': 'tertio',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 63,
#     'char_end': 69},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 70,
#     'char_end': 72},
#    {'token_text': 'omni',
#     'lemma': 'omnis',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 73,
#     'char_end': 77},
#    {'token_text': 'clero',
#     'lemma': 'clerus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 78,
#     'char_end': 83},
#    {'token_text': 'sanctae',
#     'lemma': 'sancio',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 84,
#     'char_end': 91},
#    {'token_text': 'Romanae',
#     'lemma': 'romanus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 92,
#     'char_end': 99},
#    {'token_text': 'Ecclesiae',
#     'lemma': 'ecclesia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 100,
#     'char_end': 109},
#    {'token_text': 'Deusdedit',
#     'lemma': 'deusdedit',
#     'pos': 'PROPN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 110,
#     'char_end': 119},
#    {'token_text': 'exiguus',
#     'lemma': 'exiguus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 120,
#     'char_end': 127},
#    {'token_text': 'presbyter',
#     'lemma': 'presbyter',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 128,
#     'char_end': 137},
#    {'token_text': 'tituli',
#     'lemma': 'titulus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 138,
#     'char_end': 144},
#    {'token_text': 'Apostolorum',
#     'lemma': 'apostolus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 145,
#     'char_end': 156},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 157,
#     'char_end': 159},
#    {'token_text': 'Eudoxia',
#     'lemma': 'eudoxia',
#     'pos': 'PROPN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;2', 'sent_n': '1'},
#     'char_start': 160,
#     'char_end': 167}]},
#  {'work_id': '10339',
#   'sent_id': 2,
#   'sent_text': 'Novit beatitudo vestra quod sancta Romana Ecclesia idcirco omnium Ecclesiarum mater scribitur et creditur quoniam B. Petrus ipsius institutor prius patriarchalibus sedibus in Oriente et postea e latere suo primos dedit pastores omnibus urbibus quae sunt in Occidente',
#   'token_data': [{'token_text': 'Novit',
#     'lemma': 'nosco',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 0,
#     'char_end': 5},
#    {'token_text': 'beatitudo',
#     'lemma': 'beatitudo',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 6,
#     'char_end': 15},
#    {'token_text': 'vestra',
#     'lemma': 'uester',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 16,
#     'char_end': 22},
#    {'token_text': 'quod',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 23,
#     'char_end': 27},
#    {'token_text': 'sancta',
#     'lemma': 'sanctus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 28,
#     'char_end': 34},
#    {'token_text': 'Romana',
#     'lemma': 'romanus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 35,
#     'char_end': 41},
#    {'token_text': 'Ecclesia',
#     'lemma': 'ecclesia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 42,
#     'char_end': 50},
#    {'token_text': 'idcirco',
#     'lemma': 'idcirco',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 51,
#     'char_end': 58},
#    {'token_text': 'omnium',
#     'lemma': 'omnis',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 59,
#     'char_end': 65},
#    {'token_text': 'Ecclesiarum',
#     'lemma': 'ecclesia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 66,
#     'char_end': 77},
#    {'token_text': 'mater',
#     'lemma': 'mater',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 78,
#     'char_end': 83},
#    {'token_text': 'scribitur',
#     'lemma': 'scribo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 84,
#     'char_end': 93},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 94,
#     'char_end': 96},
#    {'token_text': 'creditur',
#     'lemma': 'credo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 97,
#     'char_end': 105},
#    {'token_text': 'quoniam',
#     'lemma': 'quoniam',
#     'pos': 'SCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 106,
#     'char_end': 113},
#    {'token_text': 'B.',
#     'lemma': 'b.',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 114,
#     'char_end': 116},
#    {'token_text': 'Petrus',
#     'lemma': 'Petrus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 117,
#     'char_end': 123},
#    {'token_text': 'ipsius',
#     'lemma': 'ipse',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 124,
#     'char_end': 130},
#    {'token_text': 'institutor',
#     'lemma': 'insitutor',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 131,
#     'char_end': 141},
#    {'token_text': 'prius',
#     'lemma': 'prior',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 142,
#     'char_end': 147},
#    {'token_text': 'patriarchalibus',
#     'lemma': 'patriarchalibus',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 148,
#     'char_end': 163},
#    {'token_text': 'sedibus',
#     'lemma': 'sedes',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 164,
#     'char_end': 171},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 172,
#     'char_end': 174},
#    {'token_text': 'Oriente',
#     'lemma': 'oriens',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 175,
#     'char_end': 182},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 183,
#     'char_end': 185},
#    {'token_text': 'postea',
#     'lemma': 'postea',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 186,
#     'char_end': 192},
#    {'token_text': 'e',
#     'lemma': 'e',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 193,
#     'char_end': 194},
#    {'token_text': 'latere',
#     'lemma': 'later',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 195,
#     'char_end': 201},
#    {'token_text': 'suo',
#     'lemma': 'suus',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 202,
#     'char_end': 205},
#    {'token_text': 'primos',
#     'lemma': 'unus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 206,
#     'char_end': 212},
#    {'token_text': 'dedit',
#     'lemma': 'dedo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 213,
#     'char_end': 218},
#    {'token_text': 'pastores',
#     'lemma': 'pastor',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 219,
#     'char_end': 227},
#    {'token_text': 'omnibus',
#     'lemma': 'omnis',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 228,
#     'char_end': 235},
#    {'token_text': 'urbibus',
#     'lemma': 'urbs',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 236,
#     'char_end': 243},
#    {'token_text': 'quae',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 244,
#     'char_end': 248},
#    {'token_text': 'sunt',
#     'lemma': 'sum',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 249,
#     'char_end': 253},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 254,
#     'char_end': 256},
#    {'token_text': 'Occidente',
#     'lemma': 'occidens',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '1'},
#     'char_start': 257,
#     'char_end': 266}]},
#  {'work_id': '10339',
#   'sent_id': 3,
#   'sent_text': 'Ipsi apostolo haec ordinatio maxime competebat cui principaliter Christus Dei Filius coelestis regni clavibus traditis suas oves pascere jusserat cuique fratres suos in eadem fide confirmare praeceperat',
#   'token_data': [{'token_text': 'Ipsi',
#     'lemma': 'ipse',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 0,
#     'char_end': 4},
#    {'token_text': 'apostolo',
#     'lemma': 'apostolus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 5,
#     'char_end': 13},
#    {'token_text': 'haec',
#     'lemma': 'hic',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 14,
#     'char_end': 18},
#    {'token_text': 'ordinatio',
#     'lemma': 'ordinatio',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 19,
#     'char_end': 28},
#    {'token_text': 'maxime',
#     'lemma': 'magnus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 29,
#     'char_end': 35},
#    {'token_text': 'competebat',
#     'lemma': 'competo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 36,
#     'char_end': 46},
#    {'token_text': 'cui',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 47,
#     'char_end': 50},
#    {'token_text': 'principaliter',
#     'lemma': 'principaliter',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 51,
#     'char_end': 64},
#    {'token_text': 'Christus',
#     'lemma': 'Christus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 65,
#     'char_end': 73},
#    {'token_text': 'Dei',
#     'lemma': 'Deus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 74,
#     'char_end': 77},
#    {'token_text': 'Filius',
#     'lemma': 'filius',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 78,
#     'char_end': 84},
#    {'token_text': 'coelestis',
#     'lemma': 'coelestis',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 85,
#     'char_end': 94},
#    {'token_text': 'regni',
#     'lemma': 'regnum',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 95,
#     'char_end': 100},
#    {'token_text': 'clavibus',
#     'lemma': 'claues',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 101,
#     'char_end': 109},
#    {'token_text': 'traditis',
#     'lemma': 'trado',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 110,
#     'char_end': 118},
#    {'token_text': 'suas',
#     'lemma': 'suus',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 119,
#     'char_end': 123},
#    {'token_text': 'oves',
#     'lemma': 'ouis',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 124,
#     'char_end': 128},
#    {'token_text': 'pascere',
#     'lemma': 'pasco',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 129,
#     'char_end': 136},
#    {'token_text': 'jusserat',
#     'lemma': 'iubeo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 137,
#     'char_end': 145},
#    {'token_text': 'cuique',
#     'lemma': 'quisque',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 146,
#     'char_end': 152},
#    {'token_text': 'fratres',
#     'lemma': 'frater',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 153,
#     'char_end': 160},
#    {'token_text': 'suos',
#     'lemma': 'suus',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 161,
#     'char_end': 165},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 166,
#     'char_end': 168},
#    {'token_text': 'eadem',
#     'lemma': 'idem',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 169,
#     'char_end': 174},
#    {'token_text': 'fide',
#     'lemma': 'fides',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 175,
#     'char_end': 179},
#    {'token_text': 'confirmare',
#     'lemma': 'confirmo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 180,
#     'char_end': 190},
#    {'token_text': 'praeceperat',
#     'lemma': 'praecipio',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '2'},
#     'char_start': 191,
#     'char_end': 202}]},
#  {'work_id': '10339',
#   'sent_id': 4,
#   'sent_text': 'Cujus tam excellentissimi privilegii insignia munera diligenter attendentes 318 Patres qui in Nicaeno consederunt concilio statuerunt ut Athanasius episcopus Alexandrinus scribit B. Felici papae non debere absque Romani pontificis sententia concilia celebrari nec episcopos damnari et omnia majora negotia ad ejusdem judicium debere deferri',
#   'token_data': [{'token_text': 'Cujus',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 0,
#     'char_end': 5},
#    {'token_text': 'tam',
#     'lemma': 'tam',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 6,
#     'char_end': 9},
#    {'token_text': 'excellentissimi',
#     'lemma': 'excellentissimi',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 10,
#     'char_end': 25},
#    {'token_text': 'privilegii',
#     'lemma': 'priuilegium',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 26,
#     'char_end': 36},
#    {'token_text': 'insignia',
#     'lemma': 'insignis',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 37,
#     'char_end': 45},
#    {'token_text': 'munera',
#     'lemma': 'munus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 46,
#     'char_end': 52},
#    {'token_text': 'diligenter',
#     'lemma': 'diligenter',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 53,
#     'char_end': 63},
#    {'token_text': 'attendentes',
#     'lemma': 'attendo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 64,
#     'char_end': 75},
#    {'token_text': '318',
#     'lemma': '@card@',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 76,
#     'char_end': 79},
#    {'token_text': 'Patres',
#     'lemma': 'pater',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 80,
#     'char_end': 86},
#    {'token_text': 'qui',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 87,
#     'char_end': 90},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 91,
#     'char_end': 93},
#    {'token_text': 'Nicaeno',
#     'lemma': 'nicaeno',
#     'pos': 'PROPN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 94,
#     'char_end': 101},
#    {'token_text': 'consederunt',
#     'lemma': 'consido',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 102,
#     'char_end': 113},
#    {'token_text': 'concilio',
#     'lemma': 'concilium',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 114,
#     'char_end': 122},
#    {'token_text': 'statuerunt',
#     'lemma': 'statuo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 123,
#     'char_end': 133},
#    {'token_text': 'ut',
#     'lemma': 'ut',
#     'pos': 'SCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 134,
#     'char_end': 136},
#    {'token_text': 'Athanasius',
#     'lemma': 'athanasius',
#     'pos': 'PROPN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 137,
#     'char_end': 147},
#    {'token_text': 'episcopus',
#     'lemma': 'episcopus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 148,
#     'char_end': 157},
#    {'token_text': 'Alexandrinus',
#     'lemma': 'Alexandrinus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 158,
#     'char_end': 170},
#    {'token_text': 'scribit',
#     'lemma': 'scribo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 171,
#     'char_end': 178},
#    {'token_text': 'B.',
#     'lemma': 'b.',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 179,
#     'char_end': 181},
#    {'token_text': 'Felici',
#     'lemma': 'felix',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 182,
#     'char_end': 188},
#    {'token_text': 'papae',
#     'lemma': 'Papa',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 189,
#     'char_end': 194},
#    {'token_text': 'non',
#     'lemma': 'non',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 195,
#     'char_end': 198},
#    {'token_text': 'debere',
#     'lemma': 'debeo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 199,
#     'char_end': 205},
#    {'token_text': 'absque',
#     'lemma': 'absque',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 206,
#     'char_end': 212},
#    {'token_text': 'Romani',
#     'lemma': 'romanus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 213,
#     'char_end': 219},
#    {'token_text': 'pontificis',
#     'lemma': 'pontifex',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 220,
#     'char_end': 230},
#    {'token_text': 'sententia',
#     'lemma': 'sententia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 231,
#     'char_end': 240},
#    {'token_text': 'concilia',
#     'lemma': 'concilium',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 241,
#     'char_end': 249},
#    {'token_text': 'celebrari',
#     'lemma': 'celebro',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 250,
#     'char_end': 259},
#    {'token_text': 'nec',
#     'lemma': 'nec',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 260,
#     'char_end': 263},
#    {'token_text': 'episcopos',
#     'lemma': 'episcopus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 264,
#     'char_end': 273},
#    {'token_text': 'damnari',
#     'lemma': 'damno',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 274,
#     'char_end': 281},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 282,
#     'char_end': 284},
#    {'token_text': 'omnia',
#     'lemma': 'omnis',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 285,
#     'char_end': 290},
#    {'token_text': 'majora',
#     'lemma': 'maiora',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 291,
#     'char_end': 297},
#    {'token_text': 'negotia',
#     'lemma': 'negotium',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 298,
#     'char_end': 305},
#    {'token_text': 'ad',
#     'lemma': 'ad',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 306,
#     'char_end': 308},
#    {'token_text': 'ejusdem',
#     'lemma': 'idem',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 309,
#     'char_end': 316},
#    {'token_text': 'judicium',
#     'lemma': 'iudicium',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 317,
#     'char_end': 325},
#    {'token_text': 'debere',
#     'lemma': 'debeo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 326,
#     'char_end': 332},
#    {'token_text': 'deferri',
#     'lemma': 'defero',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '3'},
#     'char_start': 333,
#     'char_end': 340}]},
#  {'work_id': '10339',
#   'sent_id': 5,
#   'sent_text': 'Sed et Sardicense concilium quod 300 episcopos habuit teste universali synodo quae a suis conditoribus octava dicitur capitulo 3 et 4 et 6 et 9 eadem statuit et ita inter caetera B. papae Julio scripsit Optimum et valde congruentissimum esse videbitur si ad caput id est ad B. Petri apostoli sedem de singulis quibusque provinciis Domini referant sacerdotes',
#   'token_data': [{'token_text': 'Sed',
#     'lemma': 'sed',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 0,
#     'char_end': 3},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 4,
#     'char_end': 6},
#    {'token_text': 'Sardicense',
#     'lemma': 'sardicense',
#     'pos': 'PROPN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 7,
#     'char_end': 17},
#    {'token_text': 'concilium',
#     'lemma': 'concilium',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 18,
#     'char_end': 27},
#    {'token_text': 'quod',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 28,
#     'char_end': 32},
#    {'token_text': '300',
#     'lemma': '@card@',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 33,
#     'char_end': 36},
#    {'token_text': 'episcopos',
#     'lemma': 'episcopus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 37,
#     'char_end': 46},
#    {'token_text': 'habuit',
#     'lemma': 'habeo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 47,
#     'char_end': 53},
#    {'token_text': 'teste',
#     'lemma': 'testis',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 54,
#     'char_end': 59},
#    {'token_text': 'universali',
#     'lemma': 'uniuersalis',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 60,
#     'char_end': 70},
#    {'token_text': 'synodo',
#     'lemma': 'Synodus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 71,
#     'char_end': 77},
#    {'token_text': 'quae',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 78,
#     'char_end': 82},
#    {'token_text': 'a',
#     'lemma': 'a',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 83,
#     'char_end': 84},
#    {'token_text': 'suis',
#     'lemma': 'suus',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 85,
#     'char_end': 89},
#    {'token_text': 'conditoribus',
#     'lemma': 'conditor',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 90,
#     'char_end': 102},
#    {'token_text': 'octava',
#     'lemma': 'octo',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 103,
#     'char_end': 109},
#    {'token_text': 'dicitur',
#     'lemma': 'dico',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 110,
#     'char_end': 117},
#    {'token_text': 'capitulo',
#     'lemma': 'capitulum',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 118,
#     'char_end': 126},
#    {'token_text': '3',
#     'lemma': '@card@',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 127,
#     'char_end': 128},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 129,
#     'char_end': 131},
#    {'token_text': '4',
#     'lemma': '@card@',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 132,
#     'char_end': 133},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 134,
#     'char_end': 136},
#    {'token_text': '6',
#     'lemma': '@card@',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 137,
#     'char_end': 138},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 139,
#     'char_end': 141},
#    {'token_text': '9',
#     'lemma': '@card@',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 142,
#     'char_end': 143},
#    {'token_text': 'eadem',
#     'lemma': 'idem',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 144,
#     'char_end': 149},
#    {'token_text': 'statuit',
#     'lemma': 'statuo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 150,
#     'char_end': 157},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 158,
#     'char_end': 160},
#    {'token_text': 'ita',
#     'lemma': 'ita',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 161,
#     'char_end': 164},
#    {'token_text': 'inter',
#     'lemma': 'inter',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 165,
#     'char_end': 170},
#    {'token_text': 'caetera',
#     'lemma': 'caeterus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 171,
#     'char_end': 178},
#    {'token_text': 'B.',
#     'lemma': 'b.',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 179,
#     'char_end': 181},
#    {'token_text': 'papae',
#     'lemma': 'Papa',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 182,
#     'char_end': 187},
#    {'token_text': 'Julio',
#     'lemma': 'Julius',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 188,
#     'char_end': 193},
#    {'token_text': 'scripsit',
#     'lemma': 'scribo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 194,
#     'char_end': 202},
#    {'token_text': 'Optimum',
#     'lemma': 'bonus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 203,
#     'char_end': 210},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 211,
#     'char_end': 213},
#    {'token_text': 'valde',
#     'lemma': 'ualde',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 214,
#     'char_end': 219},
#    {'token_text': 'congruentissimum',
#     'lemma': 'congruentissimum',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 220,
#     'char_end': 236},
#    {'token_text': 'esse',
#     'lemma': 'sum',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 237,
#     'char_end': 241},
#    {'token_text': 'videbitur',
#     'lemma': 'uideo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 242,
#     'char_end': 251},
#    {'token_text': 'si',
#     'lemma': 'si',
#     'pos': 'SCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 252,
#     'char_end': 254},
#    {'token_text': 'ad',
#     'lemma': 'ad',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 255,
#     'char_end': 257},
#    {'token_text': 'caput',
#     'lemma': 'caput',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 258,
#     'char_end': 263},
#    {'token_text': 'id',
#     'lemma': 'is',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 264,
#     'char_end': 266},
#    {'token_text': 'est',
#     'lemma': 'sum',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 267,
#     'char_end': 270},
#    {'token_text': 'ad',
#     'lemma': 'ad',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 271,
#     'char_end': 273},
#    {'token_text': 'B.',
#     'lemma': 'b.',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 274,
#     'char_end': 276},
#    {'token_text': 'Petri',
#     'lemma': 'Petrus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 277,
#     'char_end': 282},
#    {'token_text': 'apostoli',
#     'lemma': 'apostolus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 283,
#     'char_end': 291},
#    {'token_text': 'sedem',
#     'lemma': 'sedes',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 292,
#     'char_end': 297},
#    {'token_text': 'de',
#     'lemma': 'de',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 298,
#     'char_end': 300},
#    {'token_text': 'singulis',
#     'lemma': 'singulus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 301,
#     'char_end': 309},
#    {'token_text': 'quibusque',
#     'lemma': 'quisque',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 310,
#     'char_end': 319},
#    {'token_text': 'provinciis',
#     'lemma': 'prouincia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 320,
#     'char_end': 330},
#    {'token_text': 'Domini',
#     'lemma': 'dominus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 331,
#     'char_end': 337},
#    {'token_text': 'referant',
#     'lemma': 'refero',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 338,
#     'char_end': 346},
#    {'token_text': 'sacerdotes',
#     'lemma': 'sacerdos',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '4'},
#     'char_start': 347,
#     'char_end': 357}]},
#  {'work_id': '10339',
#   'sent_id': 6,
#   'sent_text': 'Huic etiam ante illam synodum tantum reverentiae ab antiquis Patribus legitur impensem fuisse ut ille insignis martyr Cyprianus Africanae provinciae primas legatur in suis epistolis presbyterorum et diaconorum Romanam Ecclesiam post martyrium Fabiani gubernantium statutis humiliter paruisse et eorum quae apud suam provinciam gerebantur directis ad eos epistolis rationem reddidisse',
#   'token_data': [{'token_text': 'Huic',
#     'lemma': 'hic',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 0,
#     'char_end': 4},
#    {'token_text': 'etiam',
#     'lemma': 'etiam',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 5,
#     'char_end': 10},
#    {'token_text': 'ante',
#     'lemma': 'ante',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 11,
#     'char_end': 15},
#    {'token_text': 'illam',
#     'lemma': 'ille',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 16,
#     'char_end': 21},
#    {'token_text': 'synodum',
#     'lemma': 'synodum',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 22,
#     'char_end': 29},
#    {'token_text': 'tantum',
#     'lemma': 'tantus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 30,
#     'char_end': 36},
#    {'token_text': 'reverentiae',
#     'lemma': 'reuerentia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 37,
#     'char_end': 48},
#    {'token_text': 'ab',
#     'lemma': 'ab',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 49,
#     'char_end': 51},
#    {'token_text': 'antiquis',
#     'lemma': 'antiquus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 52,
#     'char_end': 60},
#    {'token_text': 'Patribus',
#     'lemma': 'pater',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 61,
#     'char_end': 69},
#    {'token_text': 'legitur',
#     'lemma': 'lego',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 70,
#     'char_end': 77},
#    {'token_text': 'impensem',
#     'lemma': 'impensem',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 78,
#     'char_end': 86},
#    {'token_text': 'fuisse',
#     'lemma': 'sum',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 87,
#     'char_end': 93},
#    {'token_text': 'ut',
#     'lemma': 'ut',
#     'pos': 'SCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 94,
#     'char_end': 96},
#    {'token_text': 'ille',
#     'lemma': 'ille',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 97,
#     'char_end': 101},
#    {'token_text': 'insignis',
#     'lemma': 'insignis',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 102,
#     'char_end': 110},
#    {'token_text': 'martyr',
#     'lemma': 'martyr',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 111,
#     'char_end': 117},
#    {'token_text': 'Cyprianus',
#     'lemma': 'Cyprianus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 118,
#     'char_end': 127},
#    {'token_text': 'Africanae',
#     'lemma': 'Africanus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 128,
#     'char_end': 137},
#    {'token_text': 'provinciae',
#     'lemma': 'prouincia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 138,
#     'char_end': 148},
#    {'token_text': 'primas',
#     'lemma': 'primas',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 149,
#     'char_end': 155},
#    {'token_text': 'legatur',
#     'lemma': 'lego',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 156,
#     'char_end': 163},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 164,
#     'char_end': 166},
#    {'token_text': 'suis',
#     'lemma': 'suus',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 167,
#     'char_end': 171},
#    {'token_text': 'epistolis',
#     'lemma': 'epistola',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 172,
#     'char_end': 181},
#    {'token_text': 'presbyterorum',
#     'lemma': 'presbyter',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 182,
#     'char_end': 195},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 196,
#     'char_end': 198},
#    {'token_text': 'diaconorum',
#     'lemma': 'diaconus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 199,
#     'char_end': 209},
#    {'token_text': 'Romanam',
#     'lemma': 'romanus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 210,
#     'char_end': 217},
#    {'token_text': 'Ecclesiam',
#     'lemma': 'ecclesia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 218,
#     'char_end': 227},
#    {'token_text': 'post',
#     'lemma': 'post',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 228,
#     'char_end': 232},
#    {'token_text': 'martyrium',
#     'lemma': 'martyrium',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 233,
#     'char_end': 242},
#    {'token_text': 'Fabiani',
#     'lemma': 'Fabianus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 243,
#     'char_end': 250},
#    {'token_text': 'gubernantium',
#     'lemma': 'guberno',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 251,
#     'char_end': 263},
#    {'token_text': 'statutis',
#     'lemma': 'statuo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 264,
#     'char_end': 272},
#    {'token_text': 'humiliter',
#     'lemma': 'humiliter',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 273,
#     'char_end': 282},
#    {'token_text': 'paruisse',
#     'lemma': 'pareo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 283,
#     'char_end': 291},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 292,
#     'char_end': 294},
#    {'token_text': 'eorum',
#     'lemma': 'is',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 295,
#     'char_end': 300},
#    {'token_text': 'quae',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 301,
#     'char_end': 305},
#    {'token_text': 'apud',
#     'lemma': 'apud',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 306,
#     'char_end': 310},
#    {'token_text': 'suam',
#     'lemma': 'suus',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 311,
#     'char_end': 315},
#    {'token_text': 'provinciam',
#     'lemma': 'prouincia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 316,
#     'char_end': 326},
#    {'token_text': 'gerebantur',
#     'lemma': 'gero',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 327,
#     'char_end': 337},
#    {'token_text': 'directis',
#     'lemma': 'dirigo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 338,
#     'char_end': 346},
#    {'token_text': 'ad',
#     'lemma': 'ad',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
#     'char_start': 347,
#     'char_end': 349},
#    {'token_text': 'eos',
#     'lemma': 'is',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;3', 'sent_n': '5'},
# ...
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 49,
#     'char_end': 52},
#    {'token_text': 'Christiano',
#     'lemma': 'Christianus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 53,
#     'char_end': 63},
#    {'token_text': 'nomine',
#     'lemma': 'nomen',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 64,
#     'char_end': 70},
#    {'token_text': 'glorietur',
#     'lemma': 'glorior',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 71,
#     'char_end': 80},
#    {'token_text': 'Christianis',
#     'lemma': 'Christianus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 81,
#     'char_end': 92},
#    {'token_text': 'temporibus',
#     'lemma': 'tempus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 93,
#     'char_end': 103},
#    {'token_text': 'Romanae',
#     'lemma': 'romanus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 104,
#     'char_end': 111},
#    {'token_text': 'Ecclesiae',
#     'lemma': 'ecclesia',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 112,
#     'char_end': 121},
#    {'token_text': 'monitis',
#     'lemma': 'moneo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 122,
#     'char_end': 129},
#    {'token_text': 'non',
#     'lemma': 'non',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 130,
#     'char_end': 133},
#    {'token_text': 'acquiescere',
#     'lemma': 'acquiesco',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 134,
#     'char_end': 145},
#    {'token_text': 'cum',
#     'lemma': 'cum',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 146,
#     'char_end': 149},
#    {'token_text': 'sub',
#     'lemma': 'sub',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 150,
#     'char_end': 153},
#    {'token_text': 'persecutionis',
#     'lemma': 'persecutio',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 154,
#     'char_end': 167},
#    {'token_text': 'crudelitate',
#     'lemma': 'crudelitas',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 168,
#     'char_end': 179},
#    {'token_text': 'Deo',
#     'lemma': 'Deus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 180,
#     'char_end': 183},
#    {'token_text': 'digni',
#     'lemma': 'dignus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 184,
#     'char_end': 189},
#    {'token_text': 'pontifices',
#     'lemma': 'pontifex',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 190,
#     'char_end': 200},
#    {'token_text': 'tam',
#     'lemma': 'tam',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 201,
#     'char_end': 204},
#    {'token_text': 'devote',
#     'lemma': 'deuote',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 205,
#     'char_end': 211},
#    {'token_text': 'paruerint',
#     'lemma': 'pareo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 212,
#     'char_end': 221},
#    {'token_text': 'etiam',
#     'lemma': 'etiam',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 222,
#     'char_end': 227},
#    {'token_text': 'dum',
#     'lemma': 'dum',
#     'pos': 'SCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 228,
#     'char_end': 231},
#    {'token_text': 'careret',
#     'lemma': 'careo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 232,
#     'char_end': 239},
#    {'token_text': 'pontifice',
#     'lemma': 'pontifex',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '1'},
#     'char_start': 240,
#     'char_end': 249}]},
#  {'work_id': '10339',
#   'sent_id': 9,
#   'sent_text': 'Arbitrati quippe sunt Patres spiritu Dei pleni beatos apostolos Petrum et Paulum in ea magnificis meritis vivere et praeesse fidemque quam ab eisdem suscepit quae in toto mundo eodem B. Paulo attestante annuntiata est et laudata in eadem usque in saecula non deficere sed ut eidem B. Petro imperatum fuerat usquequaque positos fratres in eadem fide confirmare',
#   'token_data': [{'token_text': 'Arbitrati',
#     'lemma': 'arbitro',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 0,
#     'char_end': 9},
#    {'token_text': 'quippe',
#     'lemma': 'quippe',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 10,
#     'char_end': 16},
#    {'token_text': 'sunt',
#     'lemma': 'sum',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 17,
#     'char_end': 21},
#    {'token_text': 'Patres',
#     'lemma': 'pater',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 22,
#     'char_end': 28},
#    {'token_text': 'spiritu',
#     'lemma': 'spiritus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 29,
#     'char_end': 36},
#    {'token_text': 'Dei',
#     'lemma': 'Deus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 37,
#     'char_end': 40},
#    {'token_text': 'pleni',
#     'lemma': 'plenus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 41,
#     'char_end': 46},
#    {'token_text': 'beatos',
#     'lemma': 'beatus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 47,
#     'char_end': 53},
#    {'token_text': 'apostolos',
#     'lemma': 'apostolus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 54,
#     'char_end': 63},
#    {'token_text': 'Petrum',
#     'lemma': 'Petrus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 64,
#     'char_end': 70},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 71,
#     'char_end': 73},
#    {'token_text': 'Paulum',
#     'lemma': 'Paulus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 74,
#     'char_end': 80},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 81,
#     'char_end': 83},
#    {'token_text': 'ea',
#     'lemma': 'is',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 84,
#     'char_end': 86},
#    {'token_text': 'magnificis',
#     'lemma': 'magnificis',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 87,
#     'char_end': 97},
#    {'token_text': 'meritis',
#     'lemma': 'meritum',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 98,
#     'char_end': 105},
#    {'token_text': 'vivere',
#     'lemma': 'uiuo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 106,
#     'char_end': 112},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 113,
#     'char_end': 115},
#    {'token_text': 'praeesse',
#     'lemma': 'praesum',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 116,
#     'char_end': 124},
#    {'token_text': 'fidemque',
#     'lemma': 'fidemque',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 125,
#     'char_end': 133},
#    {'token_text': 'quam',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 134,
#     'char_end': 138},
#    {'token_text': 'ab',
#     'lemma': 'ab',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 139,
#     'char_end': 141},
#    {'token_text': 'eisdem',
#     'lemma': 'idem',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 142,
#     'char_end': 148},
#    {'token_text': 'suscepit',
#     'lemma': 'suscipio',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 149,
#     'char_end': 157},
#    {'token_text': 'quae',
#     'lemma': 'qui',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 158,
#     'char_end': 162},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 163,
#     'char_end': 165},
#    {'token_text': 'toto',
#     'lemma': 'totus',
#     'pos': 'ADJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 166,
#     'char_end': 170},
#    {'token_text': 'mundo',
#     'lemma': 'mundus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 171,
#     'char_end': 176},
#    {'token_text': 'eodem',
#     'lemma': 'idem',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 177,
#     'char_end': 182},
#    {'token_text': 'B.',
#     'lemma': 'b.',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 183,
#     'char_end': 185},
#    {'token_text': 'Paulo',
#     'lemma': 'Paulus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 186,
#     'char_end': 191},
#    {'token_text': 'attestante',
#     'lemma': 'attestor',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 192,
#     'char_end': 202},
#    {'token_text': 'annuntiata',
#     'lemma': 'annuntio',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 203,
#     'char_end': 213},
#    {'token_text': 'est',
#     'lemma': 'sum',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 214,
#     'char_end': 217},
#    {'token_text': 'et',
#     'lemma': 'et',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 218,
#     'char_end': 220},
#    {'token_text': 'laudata',
#     'lemma': 'laudo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 221,
#     'char_end': 228},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 229,
#     'char_end': 231},
#    {'token_text': 'eadem',
#     'lemma': 'idem',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 232,
#     'char_end': 237},
#    {'token_text': 'usque',
#     'lemma': 'usque',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 238,
#     'char_end': 243},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 244,
#     'char_end': 246},
#    {'token_text': 'saecula',
#     'lemma': 'saeculum',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 247,
#     'char_end': 254},
#    {'token_text': 'non',
#     'lemma': 'non',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 255,
#     'char_end': 258},
#    {'token_text': 'deficere',
#     'lemma': 'deficio',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 259,
#     'char_end': 267},
#    {'token_text': 'sed',
#     'lemma': 'sed',
#     'pos': 'CCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 268,
#     'char_end': 271},
#    {'token_text': 'ut',
#     'lemma': 'ut',
#     'pos': 'SCONJ',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 272,
#     'char_end': 274},
#    {'token_text': 'eidem',
#     'lemma': 'idem',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 275,
#     'char_end': 280},
#    {'token_text': 'B.',
#     'lemma': 'b.',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 281,
#     'char_end': 283},
#    {'token_text': 'Petro',
#     'lemma': 'Petrus',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 284,
#     'char_end': 289},
#    {'token_text': 'imperatum',
#     'lemma': '-',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 290,
#     'char_end': 299},
#    {'token_text': 'fuerat',
#     'lemma': 'sum',
#     'pos': 'X',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 300,
#     'char_end': 306},
#    {'token_text': 'usquequaque',
#     'lemma': 'usquequaque',
#     'pos': 'ADV',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 307,
#     'char_end': 318},
#    {'token_text': 'positos',
#     'lemma': 'pono',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 319,
#     'char_end': 326},
#    {'token_text': 'fratres',
#     'lemma': 'frater',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 327,
#     'char_end': 334},
#    {'token_text': 'in',
#     'lemma': 'in',
#     'pos': 'ADP',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 335,
#     'char_end': 337},
#    {'token_text': 'eadem',
#     'lemma': 'idem',
#     'pos': 'PRON',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 338,
#     'char_end': 343},
#    {'token_text': 'fide',
#     'lemma': 'fides',
#     'pos': 'NOUN',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 344,
#     'char_end': 348},
#    {'token_text': 'confirmare',
#     'lemma': 'confirmo',
#     'pos': 'VERB',
#     'ref': {'div_pid': '10339:1', 'parent_pid': '10339:1;4', 'sent_n': '2'},
#     'char_start': 349,
#     'char_end': 359}]}]

# %%
metadata
# Out:
# {'title': 'Praefatio in canonum collectionem',
#  'author': 'Deusdedit cardinalis',
#  'author_viaf': 'http://viaf.org/viaf/7776051',
#  'author_viaf_id': '7776051',
#  'edition': 'early modern edition, no apparatus',
#  'editor': 'Jacques-Paul Migne',
#  'publisher': 'J. P. Migne',
#  'pub_place': 'Parisiis',
#  'pub_date': '1854',
#  'series_title': 'Patrologia Latina, vol. 150',
#  'series_id': 'DeuCar.PrInCaC',
#  'source': 'Patrologia Latina',
#  'work_id': '10339',
#  'prelemmatized': True}

# %%
target_jsons = "/srv/data/corpus-corporum/sents_jsons_dicts/"
#target_jsons = "../data/test_sents_jsons/"
os.makedirs(target_jsons, exist_ok=True)
lemmatized_metadata = []
failed = []
for filename in os.listdir(source_path):
    try:
        metadata, sentences = parse_lemmatized_cc(os.path.join(source_path, filename))
        with open(os.path.join(target_jsons,  filename.replace(".xml", ".json")), "w", encoding="utf-8") as f:
            json.dump(sentences, f, ensure_ascii=False, indent=2)
        lemmatized_metadata.append(metadata)
    except:
        failed.append(filename)

# %%
lemmatized_metadata_df = pd.DataFrame(lemmatized_metadata)

# %%
len(lemmatized_metadata_df)
# Out:
# 7690

# %%
lemmatized_metadata_df.to_csv("../data/lemmatized_metadata.csv", index=False)
